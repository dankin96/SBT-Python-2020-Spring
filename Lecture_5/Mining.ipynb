# %% [markdown]
# # Начнем с мемов

# %% [markdown]
# ![title](memes/meme_1.jpg)
# ![title](memes/meme_2.jpg)
# ![title](memes/meme_3.jpg)
# ![title](memes/meme_4.jpg)

# %% [markdown]
# # Data mining with Python

# %% [markdown]
# #### Обычно очень много внимания в процессе обучения анализу данных уделяется алгоритмам и методам обработки данных и намного меньше внимания уделяется тому эти данные взять. При этом: <br>
# - Без самих данных навряд ли что-то получится; <br>
# - От качества данных зависит результат работы любого алгоритма; (часто бывает важнее алгоритмов)<br>
# - Часто работают лучше те модели которые обучались на более качественных или большем объеме данных (70-80% работа с данными, 20-30% пробования алгоритмов).
#
# ### Где брать данные?
#
# Конечно, данные вам могут предоставить на работе или заказчик. Вы можете работать в одной из компаний где данных больше чем предостаточно. А что если их не достаточно или в них нет того что вам нужно.
#
#
# ### В этом случае лучше всего действовать в следующей последовательности:
#
# - Найти готовый датасет;
# - Собрать данные самому:
#    - для этого можно воспользоваться API;
#    - собрать данные со страниц сайтов;
#    - нагенерить/создать (видео снимали с датасетом) http://techno-start.ru/project/241/
#
#    Существует несколько инструментов для парсинга данных самостоятельно но чаще всего используют:
#     - библиотеку requests + библиотеку beautiful soup
#     - фреймворк Scrappy
# - Купить (данные новая нефть, иногда бывает выгоднее, чем потраить время фултайм программиста на скрапинг). Что делать стартапам? https://www.opendota.com/
#
#
# ### Поиск готового датасета.
# Логичнее всего начать с поиска готового датасета. Существует много сайтов где можно найти уже готовые данные, например, очень много данных есть на платформе <a href="https://www.kaggle.com/datasets">Kaggle<a/>. Менее популярная платформа, но не менее интересная <a href="http://academictorrents.com/browse.php">academictorrents.com </a>, https://datasetsearch.research.google.com/ советую проверить. <br>
#
# ODS Community datasets https://ods.ai/<br>
#
# Существуют и еще менее тривиальные источники данных о существовании которых иногда трудно догодаться. Так например, есть Google Big Querry на котором сейчас выложено около 40 публичных датасетов, один из них это все записи форума reddit. Казалось бы зачем нам форум такой форум? На самом деле применений может быть очень много, например, по его данным легко обучить классификатор текстов на разные категории, а категорий на форуме очень много. Или случай со спором<br>
# Интерфейс у Google Big Querry это SQL, что очень удобно и можно сразу вытащить то что нужно. Попробовать можно здесь: <a href="https://bigquery.cloud.google.com/results/bigdatagame-200413:US.bquijob_609efa7_16871e6cd5e?pli=1">Google Big Query</a> <br>
# Пример запроса который достает 1500 комментариве из раздела "Art" c лайками больше 5ти. <br>
#
# <strong><i>SELECT body, score FROM <br>
# `fh-bigquery.reddit_comments.2017_05` <br>
# WHERE subreddit LIKE 'Art' AND score > 5 <br>
# LIMIT 15000 <br>
# </i></strong>

# %%
### Самостоятельный сбор данных с помощью API.
Ок, если не удалось найти готовый датасет, то возможно они есть в отрытом доступе на каком-то сайте или платформе через общедоступный API. <br>
 <br>
#### Работа с API выглядит следующим образом. 
Есть два метода (на самом деле их больше GET, OPTIONS, POST, PUT, PATCH or DELETE) post и get с помощью которых мы можем обратиться к сайту или платформе. С помощью метода get мы можем можем сделать запрос ( напрмер когда мы открываем сайт по ссылке то это get), а с помощью метода post мы можем передать какеи-то значения клиенту.<br>
Так например, сайт HH.ru предоставляет свой API и по следующему запросу мы можем получить список вакансий определенной категории 1.221 (цифры обозначающие вакансии это их внутренняя кухня, тут без лишних деталей). <br>
https://api.hh.ru/vacancies?specialization=1.221 <br>
В ответ на странице вы увидите скорее всего Json фаил, который очень легко читать и с которым приятно работать. <br>
Теперь нам нужно понять что с этим делать дальше.
Минусы? (зачем)

# %% [markdown]
# ### Работа с библиотекой requests
# Собственно для работы с post и get запросами нам и понадобиться библиотека requests.

# %% [markdown]
# Для установки библиотеки используйте следующую комманду в терминале (если на Linux)
#
# pip install requests

# %% [markdown]
# Документация по библиотеке requests: https://requests.readthedocs.io/en/master/

# %% [markdown]
# ### Посмотрим на примере сайта HH.ru как работать с библиотекой и как можно получить какие-то данные с помощью API

# %%
import requests
url1 = 'https://api.hh.ru/vacancies?specialization=1.221'
url2 = 'https://api.hh.ru/vacancies/1'
resp = requests.get(url2)
print(resp.status_code)
resp = requests.get(url1)
print(resp.status_code)
# Out:
# 404
# 200

# %% [markdown]
# #### Мы видим что для одной из ссылок клиент вернул статус 404, а для другой 200.
#
# Это код ответа от клиента, код 200 обозначает что все ок, а код 404 обозначает Not found. Полный списко кодов состояния HTTP можно посмотреть <a href="https://ru.wikipedia.org/wiki/Список_кодов_состояния_HTTP"> вот здесь. </a> В дальнейшем, в рамках этого туториала нас интересует только код 200. Но на практике полезно знать и другие. (Для обработки исключений, ФБК)<br>
# И так, для одной из ссылок мы получили 200, все ок, двигаемся дальше.

# %%
print(resp.text)
print(type(resp.text))
# Out:
# {"items":[{"id":"36147933","premium":false,"name":"Web-дизайнер","department":null,"has_test":false,"response_letter_required":false,"area":{"id":"1","name":"Москва","url":"https://api.hh.ru/areas/1"},"salary":{"from":80000,"to":100000,"currency":"RUR","gross":false},"type":{"id":"open","name":"Открытая"},"address":{"city":"Москва","street":"Дегтярный переулок","building":"5с2","description":null,"lat":55.768213,"lng":37.601331,"raw":"Москва, Дегтярный переулок, 5с2","metro":{"station_name":"Тверская","line_name":"Замоскворецкая","station_id":"2.122","line_id":"2","lat":55.765343,"lng":37.603918},"metro_stations":[{"station_name":"Тверская","line_name":"Замоскворецкая","station_id":"2.122","line_id":"2","lat":55.765343,"lng":37.603918},{"station_name":"Пушкинская","line_name":"Таганско-Краснопресненская","station_id":"7.124","line_id":"7","lat":55.765607,"lng":37.604356},{"station_name":"Маяковская","line_name":"Замоскворецкая","station_id":"2.80","line_id":"2","lat":55.769808,"lng":37.596192}],"id":"1463286"},"response_url":null,"sort_point_distance":null,"employer":{"id":"3338941","name":"ПЛАНЕТА","url":"https://api.hh.ru/employers/3338941","alternate_url":"https://hh.ru/employer/3338941","logo_urls":{"original":"https://hhcdn.ru/employer-logo-original/728980.png","240":"https://hhcdn.ru/employer-logo/3357005.png","90":"https://hhcdn.ru/employer-logo/3357004.png"},"vacancies_url":"https://api.hh.ru/vacancies?employer_id=3338941","trusted":true},"published_at":"2020-03-04T23:31:57+0300","created_at":"2020-03-04T23:31:57+0300","archived":false,"apply_alternate_url":"https://hh.ru/applicant/vacancy_response?vacancyId=36147933","insider_interview":null,"url":"https://api.hh.ru/vacancies/36147933?host=hh.ru","alternate_url":"https://hh.ru/vacancy/36147933","relations":[],"snippet":{"requirement":"Высшее образование, желательно художественное. Прекрасное владение Photoshop, Adobe Illustrator, InDesign. Понимание принципов ActionScript, HTML и CSS приветствуется. Опыт работы с...","responsibility":"Разработка креативных концепций сайтов. Разработка дизайна на основе концепции. Создавать UX/UI для веб сервиса. Создание 2D и 3..."},"contacts":null},{"id":"36177717","premium":false,"name":"Дизайнер по доработке выпускных альбомов","department":null,"has_test":false,"response_letter_required":false,"area":{"id":"3","name":"Екатеринбург","url":"https://api.hh.ru/areas/3"},"salary":{"from":25000,"to":35000,"currency":"RUR","gross":false},"type":{"id":"open","name":"Открытая"},"address":null,"response_url":null,"sort_point_distance":null,"employer":{"id":"584523","name":"Яркий кадр, Студия","url":"https://api.hh.ru/employers/584523","alternate_url":"https://hh.ru/employer/584523","logo_urls":{"240":"https://hhcdn.ru/employer-logo/3207813.jpeg","90":"https://hhcdn.ru/employer-logo/3207812.jpeg","original":"https://hhcdn.ru/employer-logo-original/691670.jpg"},"vacancies_url":"https://api.hh.ru/vacancies?employer_id=584523","trusted":true},"published_at":"2020-03-06T13:03:33+0300","created_at":"2020-03-06T13:03:33+0300","archived":false,"apply_alternate_url":"https://hh.ru/applicant/vacancy_response?vacancyId=36177717","insider_interview":null,"url":"https://api.hh.ru/vacancies/36177717?host=hh.ru","alternate_url":"https://hh.ru/vacancy/36177717","relations":[],"snippet":{"requirement":"Уверенное владение программами Photoshop и Excel. Навыки в ретуши фотографии. Комбинацию творческой работы и работы на результат.","responsibility":"Доработка макетов в Photoshop по образцу (ретушь, кадрирование, внесение правок). Быть на связи через мессенджеры в рабочее время и своевременно..."},"contacts":null},{"id":"36307727","premium":false,"name":"Директор IT-управления","department":null,"has_test":false,"response_letter_required":false,"area":{"id":"1","name":"Москва","url":"https://api.hh.ru/areas/1"},"salary":null,"type":{"id":"open","name":"Открытая"},"address":{"city":"Москва","street":"1-й Нагатинский проезд","building":"10","description":null," ...
# <class 'str'>

# %%
resp.url
# Out:
# 'https://api.hh.ru/vacancies?specialization=1.221&page=2&per_page200'

# %%
resp.encoding
# Out:
# 'UTF-8'

# %%
resp.headers
# Out:
# {'Server': 'nginx', 'Date': 'Thu, 19 Mar 2020 21:37:45 GMT', 'Content-Type': 'application/json; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Keep-Alive': 'timeout=60', 'X-Request-Id': '158465386561760b769a3f5642167269, 158465386561760b769a3f5642167269', 'Cache-Control': 'max-age=0, private, must-revalidate', 'Expires': 'Thu, 06 Feb 2020 21:37:45 GMT', 'Access-Control-Allow-Origin': '*', 'Access-Control-Expose-Headers': 'Location, ETag, Date, Expires, Cache-Control, Content-Type, X-Request-ID', 'X-Frame-Options': 'SAMEORIGIN', 'X-Content-Type-Options': 'nosniff', 'Content-Encoding': 'gzip'}

# %%
resp.json()
# Out:
# {'items': [{'id': '36147933',
#    'premium': False,
#    'name': 'Web-дизайнер',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 80000, 'to': 100000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Дегтярный переулок',
#     'building': '5с2',
#     'description': None,
#     'lat': 55.768213,
#     'lng': 37.601331,
#     'raw': 'Москва, Дегтярный переулок, 5с2',
#     'metro': {'station_name': 'Тверская',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.122',
#      'line_id': '2',
#      'lat': 55.765343,
#      'lng': 37.603918},
#     'metro_stations': [{'station_name': 'Тверская',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.122',
#       'line_id': '2',
#       'lat': 55.765343,
#       'lng': 37.603918},
#      {'station_name': 'Пушкинская',
#       'line_name': 'Таганско-Краснопресненская',
#       'station_id': '7.124',
#       'line_id': '7',
#       'lat': 55.765607,
#       'lng': 37.604356},
#      {'station_name': 'Маяковская',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.80',
#       'line_id': '2',
#       'lat': 55.769808,
#       'lng': 37.596192}],
#     'id': '1463286'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'employer': {'id': '3338941',
#     'name': 'ПЛАНЕТА',
#     'url': 'https://api.hh.ru/employers/3338941',
#     'alternate_url': 'https://hh.ru/employer/3338941',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/728980.png',
#      '240': 'https://hhcdn.ru/employer-logo/3357005.png',
#      '90': 'https://hhcdn.ru/employer-logo/3357004.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3338941',
#     'trusted': True},
#    'published_at': '2020-03-04T23:31:57+0300',
#    'created_at': '2020-03-04T23:31:57+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=36147933',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/36147933?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/36147933',
#    'relations': [],
#    'snippet': {'requirement': 'Высшее образование, желательно художественное. Прекрасное владение Photoshop, Adobe Illustrator, InDesign. Понимание принципов ActionScript, HTML и CSS приветствуется. Опыт работы с...',
#     'responsibility': 'Разработка креативных концепций сайтов. Разработка дизайна на основе концепции. Создавать UX/UI для веб сервиса. Создание 2D и 3...'},
#    'contacts': None},
#   {'id': '36177717',
#    'premium': False,
#    'name': 'Дизайнер по доработке выпускных альбомов',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '3',
#     'name': 'Екатеринбург',
#     'url': 'https://api.hh.ru/areas/3'},
#    'salary': {'from': 25000, 'to': 35000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'employer': {'id': '584523',
#     'name': 'Яркий кадр, Студия',
#     'url': 'https://api.hh.ru/employers/584523',
#     'alternate_url': 'https://hh.ru/employer/584523',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3207813.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3207812.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/691670.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=584523',
#     'trusted': True},
#    'published_at': '2020-03-06T13:03:33+0300',
#    'created_at': '2020-03-06T13:03:33+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=36177717',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/36177717?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/36177717',
#    'relations': [],
#    'snippet': {'requirement': 'Уверенное владение программами Photoshop и Excel. Навыки в ретуши фотографии. Комбинацию творческой работы и работы на результат.',
#     'responsibility': 'Доработка макетов в Photoshop по образцу (ретушь, кадрирование, внесение правок). Быть на связи через мессенджеры в рабочее время и своевременно...'},
#    'contacts': None},
#   {'id': '36307727',
#    'premium': False,
#    'name': 'Директор IT-управления',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': '1-й Нагатинский проезд',
#     'building': '10',
#     'description': None,
#     'lat': 55.678418,
#     'lng': 37.632278,
#     'raw': 'Москва, 1-й Нагатинский проезд, 10',
#     'metro': {'station_name': 'Нагатинская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.85',
#      'line_id': '9',
#      'lat': 55.682099,
#      'lng': 37.620917},
#     'metro_stations': [{'station_name': 'Нагатинская',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.85',
#       'line_id': '9',
#       'lat': 55.682099,
#       'lng': 37.620917}],
#     'id': '495185'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'employer': {'id': '28118',
#     'name': 'Баусервис',
#     'url': 'https://api.hh.ru/employers/28118',
#     'alternate_url': 'https://hh.ru/employer/28118',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=28118',
#     'trusted': True},
#    'published_at': '2020-03-16T11:59:41+0300',
#    'created_at': '2020-03-16T11:59:41+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=36307727',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/36307727?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/36307727',
#    'relations': [],
#    'snippet': {'requirement': 'Высшее образование (техническое/ИТ). Опыт управления полной ИТ-структурой в компаниях с региональной сетью/представительствами от 10 лет. ',
#     'responsibility': 'Аудит состояния управления ИТ в компании. Анализ функций, численности подразделения. Разработка стратегии и тактики ИТ-развития. Организация планирования и использования...'},
#    'contacts': {'name': 'Арефьева Ольга',
#     'email': None,
#     'phones': [{'comment': '(доб. 3853)',
#       'city': '495',
#       'number': '6003610',
#       'country': '7'}]}},
#   {'id': '36230293',
#    'premium': False,
#    'name': 'Менеджер интернет-проектов / Project manager',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '2',
#     'name': 'Санкт-Петербург',
#     'url': 'https://api.hh.ru/areas/2'},
#    'salary': {'from': 40000, 'to': 100000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': None,
#     'street': None,
#     'building': None,
#     'description': None,
#     'lat': None,
#     'lng': None,
#     'raw': None,
#     'metro': {'station_name': 'Нарвская',
#      'line_name': 'Кировско-Выборгская',
#      'station_id': '14.204',
#      'line_id': '14',
#      'lat': 59.901218,
#      'lng': 30.274908},
#     'metro_stations': [{'station_name': 'Нарвская',
#       'line_name': 'Кировско-Выборгская',
#       'station_id': '14.204',
#       'line_id': '14',
#       'lat': 59.901218,
#       'lng': 30.274908},
#      {'station_name': 'Балтийская',
#       'line_name': 'Кировско-Выборгская',
#       'station_id': '14.203',
#       'line_id': '14',
#       'lat': 59.907211,
#       'lng': 30.299578}],
#     'id': '3711870'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'employer': {'id': '4420060',
#     'name': 'Компания Effect',
#     'url': 'https://api.hh.ru/employers/4420060',
#     'alternate_url': 'https://hh.ru/employer/4420060',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/3249264.png',
#      '240': 'https://hhcdn.ru/employer-logo/3249265.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/702037.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4420060',
#     'trusted': True},
#    'published_at': '2020-03-11T11:43:10+0300',
#    'created_at': '2020-03-11T11:43:10+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=36230293',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/36230293?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/36230293',
#    'relations': [],
#    'snippet': {'requirement': 'Желателен опыт в интернет-маркетинге. Коммуникабельность, обучаемость. Умение общаться с клиентами, находить общий язык и донести нужную информацию. ',
#     'responsibility': 'Ведение проектов по разработке сайтов. Прием входящих обращений, ведение лида до продажи. Ведение документации. Расчет стоимости и сроков разработки сайтов. '},
#    'contacts': {'name': 'Александр',
#     'email': 'info@effect78.ru',
#     'phones': [{'comment': 'с 9 до 18',
#       'city': '812',
#       'number': '6005411',
#       'country': '7'},
#      {'comment': 'с 9 до 18',
#       'city': '921',
#       'number': '3592800',
#       'country': '7'}]}},
#   {'id': '36177716',
#    'premium': False,
#    'name': 'Дизайнер по доработке выпускных альбомов',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '4',
#     'name': 'Новосибирск',
#     'url': 'https://api.hh.ru/areas/4'},
#    'salary': {'from': 25000, 'to': 35000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'employer': {'id': '584523',
#     'name': 'Яркий кадр, Студия',
#     'url': 'https://api.hh.ru/employers/584523',
#     'alternate_url': 'https://hh.ru/employer/584523',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3207813.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3207812.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/691670.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=584523',
#     'trusted': True},
#    'published_at': '2020-03-06T13:03:33+0300',
#    'created_at': '2020-03-06T13:03:33+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=36177716',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/36177716?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/36177716',
#    'relations': [],
#    'snippet': {'requirement': 'Уверенное владение программами Photoshop и Excel. Навыки в ретуши фотографии. Комбинацию творческой работы и работы на результат.',
#     'responsibility': 'Доработка макетов в Photoshop по образцу (ретушь, кадрирование, внесение правок). Быть на связи через мессенджеры в рабочее время и своевременно...'},
#    'contacts': None},
#   {'id': '36297256',
#    'premium': False,
#    'name': 'Web-дизайнер',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Профсоюзная улица',
#     'building': '7/12',
#     'description': None,
#     'lat': 55.683097,
#     'lng': 37.570384,
#     'raw': 'Москва, Профсоюзная улица, 7/12',
#     'metro': {'station_name': 'Академическая',
#      'line_name': 'Калужско-Рижская',
#      'station_id': '6.3',
#      'line_id': '6',
#      'lat': 55.687147,
#      'lng': 37.5723},
#     'metro_stations': [{'station_name': 'Академическая',
#       'line_name': 'Калужско-Рижская',
#       'station_id': '6.3',
#       'line_id': '6',
#       'lat': 55.687147,
#       'lng': 37.5723}],
#     'id': '127102'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'employer': {'id': '848515',
#     'name': 'Агентство коммуникаций AVANT',
#     'url': 'https://api.hh.ru/employers/848515',
#     'alternate_url': 'https://hh.ru/employer/848515',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/1530358.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/271957.png',
#      '240': 'https://hhcdn.ru/employer-logo/1530359.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=848515',
#     'trusted': True},
#    'published_at': '2020-03-15T21:33:02+0300',
#    'created_at': '2020-03-15T21:33:02+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=36297256',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/36297256?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/36297256',
#    'relations': [],
#    'snippet': {'requirement': 'Опыт работы от 1 года на аналогичной должности. Опыт работы над веб-проектами различной сложности. Опыт создания презентаций. ',
#     'responsibility': 'Участие в разработке креативных концепций в составе креативной команды. Создание графических и стилистических элементов для различных web - продуктов (сайты, лендинги...'},
#    'contacts': {'name': 'Ольга',
#     'email': 'hr@avantmedia.ru',
#     'phones': [{'comment': None,
#       'city': '965',
#       'number': '1908265',
#       'country': '7'}]}},
#   {'id': '36254944',
#    'premium': False,
#    'name': 'Младший руководитель проектов',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 60000, 'to': 80000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'employer': {'id': '2119774',
#     'name': 'VoltMobi',
#     'url': 'https://api.hh.ru/employers/2119774',
#     'alternate_url': 'https://hh.ru/employer/2119774',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/1794091.png',
#      '90': 'https://hhcdn.ru/employer-logo/1794090.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/337956.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2119774',
#     'trusted': True},
#    'published_at': '2020-03-12T10:19:03+0300',
#    'created_at': '2020-03-12T10:19:03+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=36254944',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/36254944?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/36254944',
#    'relations': [],
#    'snippet': {'requirement': 'Ответственность. Доведение работы до необходимого результата в срок. Коммуникабельность. Умение доносить необходимую информацию и воспринимать конструктивную критику/обратную связь. ',
#     'responsibility': 'Контролировать расписание проекта и управлять рисками. Осуществлять удаленную координацию между участниками проекта разной специализации (дизайнеры, разработчики, тестеры, администраторы, аналитики и...'},
#    'contacts': None},
#   {'id': '31445387',
#    'premium': False,
#    'name': 'Программист 1С (2ая линия поддержки) [id15849]',
#    'department': {'id': 'gpn-39305-HOLD', 'name': 'ПАО «Газпром нефть»'},
#    'has_test': True,
#    'response_letter_required': False,
#    'area': {'id': '2',
#     'name': 'Санкт-Петербург',
#     'url': 'https://api.hh.ru/areas/2'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Санкт-Петербург',
#     'street': 'Рощинская улица',
#     'building': '3',
#     'description': None,
#     'lat': 59.885164,
#     'lng': 30.310074,
#     'raw': 'Санкт-Петербург, Рощинская улица, 3',
#     'metro': {'station_name': 'Электросила',
#      'line_name': 'Московско-Петроградская',
#      'station_id': '15.222',
#      'line_id': '15',
#      'lat': 59.879189,
#      'lng': 30.318659},
#     'metro_stations': [{'station_name': 'Электросила',
#       'line_name': 'Московско-Петроградская',
#       'station_id': '15.222',
#       'line_id': '15',
#       'lat': 59.879189,
#       'lng': 30.318659},
#      {'station_name': 'Московские ворота',
#       'line_name': 'Московско-Петроградская',
#       'station_id': '15.221',
#       'line_id': '15',
#       'lat': 59.891788,
#       'lng': 30.317873}],
#     'id': '3135397'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'employer': {'id': '39305',
#     'name': 'Газпром нефть',
#     'url': 'https://api.hh.ru/employers/39305',
#     'alternate_url': 'https://hh.ru/employer/39305',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/223851.gif',
#      '90': 'https://hhcdn.ru/employer-logo/317800.png',
#      '240': 'https://hhcdn.ru/employer-logo/390657.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=39305',
#     'trusted': True},
#    'published_at': '2020-03-02T10:28:15+0300',
#    'created_at': '2020-03-02T10:28:15+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=31445387',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/31445387?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/31445387',
#    'relations': [],
#    'snippet': {'requirement': 'Высшее образование по направлениям: прикладная математика, информатика, компьютерная электроника, математические методы в экономике. Общие принципы построения и организации локальных вычислительных...',
#     'responsibility': 'Оказание поддержки пользователей корпоративных систем на базе решений 1С: ERP, Документооборот, УПП, Управление холдингом, Консолидация. Консультационная поддержка, администрирование информационной...'},
#    'contacts': None},
#   {'id': '36177719',
#    'premium': False,
#    'name': 'Дизайнер по доработке выпускных альбомов',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '66',
#     'name': 'Нижний Новгород',
#     'url': 'https://api.hh.ru/areas/66'},
#    'salary': {'from': 25000, 'to': 35000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'employer': {'id': '584523',
#     'name': 'Яркий кадр, Студия',
#     'url': 'https://api.hh.ru/employers/584523',
#     'alternate_url': 'https://hh.ru/employer/584523',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3207813.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3207812.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/691670.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=584523',
#     'trusted': True},
#    'published_at': '2020-03-06T13:03:33+0300',
#    'created_at': '2020-03-06T13:03:33+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=36177719',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/36177719?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/36177719',
#    'relations': [],
#    'snippet': {'requirement': 'Уверенное владение программами Photoshop и Excel. Навыки в ретуши фотографии. Комбинацию творческой работы и работы на результат.',
#     'responsibility': 'Доработка макетов в Photoshop по образцу (ретушь, кадрирование, внесение правок). Быть на связи через мессенджеры в рабочее время и своевременно...'},
#    'contacts': None},
#   {'id': '33025848',
#    'premium': False,
#    'name': 'Руководитель IT проектов',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Большая Спасская улица',
#     'building': '20с3',
#     'description': None,
#     'lat': 55.775358,
#     'lng': 37.642995,
#     'raw': 'Москва, Большая Спасская улица, 20с3',
#     'metro': {'station_name': 'Комсомольская',
#      'line_name': 'Сокольническая',
#      'station_id': '1.54',
#      'line_id': '1',
#      'lat': 55.774072,
#      'lng': 37.654565},
#     'metro_stations': [{'station_name': 'Комсомольская',
#       'line_name': 'Сокольническая',
#       'station_id': '1.54',
#       'line_id': '1',
#       'lat': 55.774072,
#       'lng': 37.654565},
#      {'station_name': 'Сухаревская',
#       'line_name': 'Калужско-Рижская',
#       'station_id': '6.137',
#       'line_id': '6',
#       'lat': 55.772315,
#       'lng': 37.63285},
#      {'station_name': 'Комсомольская',
#       'line_name': 'Кольцевая',
#       'station_id': '5.55',
#       'line_id': '5',
#       'lat': 55.775672,
#       'lng': 37.654772}],
#     'id': '295970'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'employer': {'id': '935653',
#     'name': 'Сентинел Кредит Менеджмент',
#     'url': 'https://api.hh.ru/employers/935653',
#     'alternate_url': 'https://hh.ru/employer/935653',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/682752.png',
#      '240': 'https://hhcdn.ru/employer-logo/3172141.png',
#      '90': 'https://hhcdn.ru/employer-logo/3172140.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=935653',
#     'trusted': True},
#    'published_at': '2020-03-16T18:08:20+0300',
#    'created_at': '2020-03-16T18:08:20+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=33025848',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/33025848?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/33025848',
#    'relations': [],
#    'snippet': {'requirement': None,
#     'responsibility': 'Сопровождение текущих ИТ проектов Компании. Подготовка и проведение презентаций менеджменту по статусу проектов. Формирование и согласование ТЗ на доработку систем. '},
#    'contacts': {'name': 'Новикова Анастасия',
#     'email': 'agnovikova@sentinelcredit.ru',
#     'phones': []}},
#   {'id': '35985607',
#    'premium': False,
#    'name': 'Web-дизайнер',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'employer': {'id': '4260488',
#     'name': 'Свадебный портал',
#     'url': 'https://api.hh.ru/employers/4260488',
#     'alternate_url': 'https://hh.ru/employer/4260488',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4260488',
#     'trusted': True},
#    'published_at': '2020-02-25T10:15:47+0300',
#    'created_at': '2020-02-25T10:15:47+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=35985607',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/35985607?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/35985607',
#    'relations': [],
#    'snippet': {'requirement': 'Знание основ web дизайна. Хороший вкус.',
#     'responsibility': 'Выполнять отдельные задачи по дизайну сайта.'},
#    'contacts': None},
#   {'id': '36194063',
#    'premium': False,
#    'name': 'Ведущий Web-разработчик PHP/JS (full stack)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 150000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'employer': {'id': '92258',
#     'name': 'Север Авто М',
#     'url': 'https://api.hh.ru/employers/92258',
#     'alternate_url': 'https://hh.ru/employer/92258',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/1573302.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/282726.jpg',
#      '240': 'https://hhcdn.ru/employer-logo/1573303.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=92258',
#     'trusted': True},
#    'published_at': '2020-03-10T07:57:30+0300',
#    'created_at': '2020-03-10T07:57:30+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=36194063',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/36194063?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/36194063',
#    'relations': [],
#    'snippet': {'requirement': 'Опыт работы и уверенное владение PHP, Javascript, jQuery от 3 лет. Знание CSS3. Знание фреймфорка React. Хорошее понимание ООП...',
#     'responsibility': 'Участие в разработке новых больших интернет-проектов в сфере B2B и B2C. Участие в разработке внутренних...'},
#    'contacts': {'name': 'Полина',
#     'email': 'vitolinsh.pu@svrauto.ru',
#     'phones': [{'comment': 'доб.1326',
#       'city': '903',
#       'number': '7232242',
#       'country': '7'},
#      {'comment': 'доб.1326',
#       'city': '495',
#       'number': '5442120',
#       'country': '7'}]}},
#   {'id': '36304064',
#    'premium': False,
#    'name': 'Frontend developer (Javascript, React)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 1500, 'to': 3500, 'currency': 'USD', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Мамоновский переулок',
#     'building': '4 офис 6',
#     'description': None,
#     'lat': 55.765863,
#     'lng': 37.598205,
#     'raw': 'Москва, Мамоновский переулок, 4 офис 6',
#     'metro': {'station_name': 'Тверская',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.122',
#      'line_id': '2',
#      'lat': 55.765343,
#      'lng': 37.603918},
#     'metro_stations': [{'station_name': 'Тверская',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.122',
#       'line_id': '2',
#       'lat': 55.765343,
#       'lng': 37.603918}],
#     'id': '86345'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'employer': {'id': '816284',
#     'name': 'Bright Pattern, Inc',
#     'url': 'https://api.hh.ru/employers/816284',
#     'alternate_url': 'https://hh.ru/employer/816284',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/1078358.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/133618.png',
#      '240': 'https://hhcdn.ru/employer-logo/1078359.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=816284',
#     'trusted': True},
#    'published_at': '2020-03-16T10:34:54+0300',
#    'created_at': '2020-03-16T10:34:54+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=36304064',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/36304064?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/36304064',
#    'relations': [],
#    'snippet': {'requirement': 'Опыт разработки на JavaScript от 3 лет, опыт использования React.Js. Хорошее понимание веб-разметки, HTML5 и CSS3. ',
#     'responsibility': 'Участие в создании сложного высоконагруженного продукта с реальными пользователями.'},
#    'contacts': {'name': 'Оксана',
#     'email': 'oksana.kuzewalowa@brightpattern.com',
#     'phones': [{'comment': None,
#       'city': '960',
#       'number': '5323151',
#       'country': '7'}]}},
#   {'id': '35360439',
#    'premium': False,
#    'name': 'Product owner',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'employer': {'id': '4317138',
#     'name': 'Софтмашина',
#     'url': 'https://api.hh.ru/employers/4317138',
#     'alternate_url': 'https://hh.ru/employer/4317138',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/722797.png',
#      '90': 'https://hhcdn.ru/employer-logo/3332284.png',
#      '240': 'https://hhcdn.ru/employer-logo/3332285.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4317138',
#     'trusted': True},
#    'published_at': '2020-03-17T10:23:19+0300',
#    'created_at': '2020-03-17T10:23:19+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=35360439',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/35360439?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/35360439',
#    'relations': [],
#    'snippet': {'requirement': 'Высшее образование, предпочтительно техническое. Широкий кругозор в IT и разработке цифровых продуктов. Опыт работы управления проектами. Опыт управления успешными проектами. ',
#     'responsibility': 'Управление продуктом (проектом) согласно идеологии Agile: с применением одного из фреймворков (либо их совмещением): Scrum, Kanban. Декомпозиция продукта на составляющие...'},
#    'contacts': None},
#   {'id': '36211829',
#    'premium': False,
#    'name': 'Руководитель проектов',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 140000, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'employer': {'id': '2888597',
#     'name': 'РеИнформ Инт.',
#     'url': 'https://api.hh.ru/employers/2888597',
#     'alternate_url': 'https://hh.ru/employer/2888597',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/2648254.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/2648253.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/551695.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2888597',
#     'trusted': True},
#    'published_at': '2020-03-19T15:37:42+0300',
#    'created_at': '2020-03-19T15:37:42+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=36211829',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/36211829?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/36211829',
#    'relations': [],
#    'snippet': {'requirement': 'Опыт работы со стеком Atlassian (Jira, Confluence). Знания Project management. Навыки управления рисками, проведения переговоров, проведения презентаций. Ответственность. ',
#     'responsibility': 'Управление проектами разработки и внедрения ПО. Руководство проектной командой. Управление рисками в проекте. Выстраивание коммуникаций в проекте. Проведение деловых переговоров...'},
#    'contacts': None},
#   {'id': '36241633',
#    'premium': False,
#    'name': 'Web-дизайнер',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': '4-й Лесной переулок',
#     'building': '4',
#     'description': None,
#     'lat': 55.779064,
#     'lng': 37.586922,
#     'raw': 'Москва, 4-й Лесной переулок, 4',
#     'metro': {'station_name': 'Белорусская',
#      'line_name': 'Кольцевая',
#      'station_id': '5.20',
#      'line_id': '5',
#      'lat': 55.775179,
#      'lng': 37.582303},
#     'metro_stations': [{'station_name': 'Белорусская',
#       'line_name': 'Кольцевая',
#       'station_id': '5.20',
#       'line_id': '5',
#       'lat': 55.775179,
#       'lng': 37.582303}],
#     'id': '2745583'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'employer': {'id': '223129',
#     'name': 'Лига Ставок',
#     'url': 'https://api.hh.ru/employers/223129',
#     'alternate_url': 'https://hh.ru/employer/223129',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/641719.png',
#      '90': 'https://hhcdn.ru/employer-logo/3008028.png',
#      '240': 'https://hhcdn.ru/employer-logo/3008029.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=223129',
#     'trusted': True},
#    'published_at': '2020-03-11T16:33:10+0300',
#    'created_at': '2020-03-11T16:33:10+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=36241633',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/36241633?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/36241633',
#    'relations': [],
#    'snippet': {'requirement': 'Опыт работы в диджитал дизайне от 3 лет. Умение создавать дизайн-концепции для разных носителей. Навыки в техническом дизайне (коллажирование...',
#     'responsibility': 'Проектирование посадочных промо-страниц и веб-интерфейсов. Создание креативных концепций промоакций с нуля. Разработка анимированных баннеров HTML-5. '},
#    'contacts': None},
#   {'id': '36317928',
#    'premium': False,
#    'name': 'Дизайнер UI/UX',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Ленинградский проспект',
#     'building': '36с11',
#     'description': None,
#     'lat': 55.788353,
#     'lng': 37.567922,
#     'raw': 'Москва, Ленинградский проспект, 36с11',
#     'metro': None,
#     'metro_stations': [],
#     'id': '3727328'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'employer': {'id': '197135',
#     'name': 'ИК СИБИНТЕК',
#     'url': 'https://api.hh.ru/employers/197135',
#     'alternate_url': 'https://hh.ru/employer/197135',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/1888930.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/361668.png',
#      '240': 'https://hhcdn.ru/employer-logo/1888931.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=197135',
#     'trusted': True},
#    'published_at': '2020-03-16T16:51:02+0300',
#    'created_at': '2020-03-16T16:51:02+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=36317928',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/36317928?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/36317928',
#    'relations': [],
#    'snippet': {'requirement': 'Опыт работы дизайнером не менее 3 лет. Уверенное владение растровой и векторной графикой на базе Adobe CC. Уверенное владение инструментами...',
#     'responsibility': 'Реализация проектов в составе команды по разработке информационных систем с использованием технологий машинного обучения. Прототипирование и визуализация интерфейсов. '},
#    'contacts': None},
#   {'id': '36177715',
#    'premium': False,
#    'name': 'Дизайнер по доработке выпускных альбомов',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '76',
#     'name': 'Ростов-на-Дону',
#     'url': 'https://api.hh.ru/areas/76'},
#    'salary': {'from': 25000, 'to': 35000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'employer': {'id': '584523',
#     'name': 'Яркий кадр, Студия',
#     'url': 'https://api.hh.ru/employers/584523',
#     'alternate_url': 'https://hh.ru/employer/584523',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3207813.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3207812.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/691670.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=584523',
#     'trusted': True},
#    'published_at': '2020-03-06T13:03:33+0300',
#    'created_at': '2020-03-06T13:03:33+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=36177715',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/36177715?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/36177715',
#    'relations': [],
#    'snippet': {'requirement': 'Уверенное владение программами Photoshop и Excel. Навыки в ретуши фотографии. Комбинацию творческой работы и работы на результат.',
#     'responsibility': 'Доработка макетов в Photoshop по образцу (ретушь, кадрирование, внесение правок). Быть на связи через мессенджеры в рабочее время и своевременно...'},
#    'contacts': None},
#   {'id': '36308825',
#    'premium': False,
#    'name': 'Web-дизайнер',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 60000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': '2-я Рощинская улица',
#     'building': '10',
#     'description': None,
#     'lat': 55.7100324329,
#     'lng': 37.6131051626,
#     'raw': 'Москва, 2-я Рощинская улица, 10',
#     'metro': {'station_name': 'Тульская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.142',
#      'line_id': '9',
#      'lat': 55.70961,
#      'lng': 37.622569},
#     'metro_stations': [{'station_name': 'Тульская',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.142',
#       'line_id': '9',
#       'lat': 55.70961,
#       'lng': 37.622569}],
#     'id': '761093'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'employer': {'id': '1121745',
#     'name': 'СтройИндустрия',
#     'url': 'https://api.hh.ru/employers/1121745',
#     'alternate_url': 'https://hh.ru/employer/1121745',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/390859.jpg',
#      '90': 'https://hhcdn.ru/employer-logo/2005690.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/2005691.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1121745',
#     'trusted': True},
#    'published_at': '2020-03-19T12:29:38+0300',
#    'created_at': '2020-03-19T12:29:38+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=36308825',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/36308825?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/36308825',
#    'relations': [],
#    'snippet': {'requirement': 'Владение графическим пакетом программ: Adobe Photoshop, Adobe illustrator, Adobe Acrobat, Adobe InDesign и др.. Чувство вкуса и стиля. ',
#     'responsibility': 'Создание макетов страниц сайта (посадочная страница), информация о новинках, акциях, событиях, для размещения на сайте компании и в социальных сетях. '},
#    'contacts': {'name': 'Юлия',
#     'email': 'egorova@s-m-r.ru',
#     'phones': [{'comment': None,
#       'city': '903',
#       'number': '7491737',
#       'country': '7'}]}},
#   {'id': '32550121',
#    'premium': False,
#    'name': 'Ведущий специалист поддержки систем 1С:ЕRP/УХ [id21689/id19761]',
#    'department': {'id': 'gpn-39305-HOLD', 'name': 'ПАО «Газпром нефть»'},
#    'has_test': True,
#    'response_letter_required': False,
#    'area': {'id': '4',
#     'name': 'Новосибирск',
#     'url': 'https://api.hh.ru/areas/4'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Новосибирск',
#     'street': 'Октябрьская улица',
#     'building': '52',
#     'description': None,
#     'lat': 55.024688,
#     'lng': 82.92352,
#     'raw': 'Новосибирск, Октябрьская улица, 52',
#     'metro': {'station_name': 'Площадь Ленина',
#      'line_name': 'Ленинская',
#      'station_id': '52.297',
#      'line_id': '52',
#      'lat': 55.029941,
#      'lng': 82.92069},
#     'metro_stations': [{'station_name': 'Площадь Ленина',
#       'line_name': 'Ленинская',
#       'station_id': '52.297',
#       'line_id': '52',
#       'lat': 55.029941,
#       'lng': 82.92069}],
#     'id': '470430'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'employer': {'id': '39305',
#     'name': 'Газпром нефть',
#     'url': 'https://api.hh.ru/employers/39305',
#     'alternate_url': 'https://hh.ru/employer/39305',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/223851.gif',
#      '90': 'https://hhcdn.ru/employer-logo/317800.png',
#      '240': 'https://hhcdn.ru/employer-logo/390657.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=39305',
#     'trusted': True},
#    'published_at': '2020-03-02T10:28:15+0300',
#    'created_at': '2020-03-02T10:28:15+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=32550121',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/32550121?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/32550121',
#    'relations': [],
#    'snippet': {'requirement': 'Знание подсистем типовой конфигурации 1С:ЕRP/1С:УХ. Знание основ бухгалтерского, налогового, управленческого учетов. Отличные знания платформы 1...',
#     'responsibility': 'Техническая поддержка систем 1С по соответствующему направлению. Проведение регламентных работ и выполнение регламентных процедур, необходимых для корректной работы обслуживаемых...'},
#    'contacts': None}],
#  'found': 30458,
#  'pages': 100,
#  'per_page': 20,
#  'page': 0,
#  'clusters': None,
#  'arguments': None,
#  'alternate_url': 'https://hh.ru/search/vacancy?enable_snippets=true&specialization=1.221'}

# %%
url=url1+'&page=2&per_page200'
resp = requests.get(url)
print(resp)
# Out:
# <Response [200]>

# %% [markdown]
# '&page=1&per_page100'  - это опять внутренняя кухня API HH.ru, у всех платформ она разная. Здесь мы говорим что мы загружаем первую страницу и 100 результатов на странице. Почему нельзя сделать больше или подругому за раз зависит от того как это решили разработчики API. <br>
# Но можно получить больше результатов следующим образом.

# %%
searches = []
for page in range(20): #что если больше?
    searches.append(
        requests.get(url1 + '&page={}&per_page=100'.format(page)).json()
    )

# %%
#Можно открыть первую ссылку в нашем дасатае и посмотреть что мы собрали.
searches[0]['items'][0]['url']
# Out:
# 'https://api.hh.ru/vacancies/36147933?host=hh.ru'

# %%
searches[0]['items'][0].keys()
# Out:
# dict_keys(['id', 'premium', 'name', 'department', 'has_test', 'response_letter_required', 'area', 'salary', 'type', 'address', 'response_url', 'sort_point_distance', 'employer', 'published_at', 'created_at', 'archived', 'apply_alternate_url', 'insider_interview', 'url', 'alternate_url', 'relations', 'snippet', 'contacts'])

# %%
vacs = [x['items'] for x in searches]
vacs = sum(list(vacs),[])
vacs[0]
# Out:
# {'id': '36147933',
#  'premium': False,
#  'name': 'Web-дизайнер',
#  'department': None,
#  'has_test': False,
#  'response_letter_required': False,
#  'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#  'salary': {'from': 80000, 'to': 100000, 'currency': 'RUR', 'gross': False},
#  'type': {'id': 'open', 'name': 'Открытая'},
#  'address': {'city': 'Москва',
#   'street': 'Дегтярный переулок',
#   'building': '5с2',
#   'description': None,
#   'lat': 55.768213,
#   'lng': 37.601331,
#   'raw': 'Москва, Дегтярный переулок, 5с2',
#   'metro': {'station_name': 'Тверская',
#    'line_name': 'Замоскворецкая',
#    'station_id': '2.122',
#    'line_id': '2',
#    'lat': 55.765343,
#    'lng': 37.603918},
#   'metro_stations': [{'station_name': 'Тверская',
#     'line_name': 'Замоскворецкая',
#     'station_id': '2.122',
#     'line_id': '2',
#     'lat': 55.765343,
#     'lng': 37.603918},
#    {'station_name': 'Пушкинская',
#     'line_name': 'Таганско-Краснопресненская',
#     'station_id': '7.124',
#     'line_id': '7',
#     'lat': 55.765607,
#     'lng': 37.604356},
#    {'station_name': 'Маяковская',
#     'line_name': 'Замоскворецкая',
#     'station_id': '2.80',
#     'line_id': '2',
#     'lat': 55.769808,
#     'lng': 37.596192}],
#   'id': '1463286'},
#  'response_url': None,
#  'sort_point_distance': None,
#  'employer': {'id': '3338941',
#   'name': 'ПЛАНЕТА',
#   'url': 'https://api.hh.ru/employers/3338941',
#   'alternate_url': 'https://hh.ru/employer/3338941',
#   'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/728980.png',
#    '240': 'https://hhcdn.ru/employer-logo/3357005.png',
#    '90': 'https://hhcdn.ru/employer-logo/3357004.png'},
#   'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3338941',
#   'trusted': True},
#  'published_at': '2020-03-04T23:31:57+0300',
#  'created_at': '2020-03-04T23:31:57+0300',
#  'archived': False,
#  'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=36147933',
#  'insider_interview': None,
#  'url': 'https://api.hh.ru/vacancies/36147933?host=hh.ru',
#  'alternate_url': 'https://hh.ru/vacancy/36147933',
#  'relations': [],
#  'snippet': {'requirement': 'Высшее образование, желательно художественное. Прекрасное владение Photoshop, Adobe Illustrator, InDesign. Понимание принципов ActionScript, HTML и CSS приветствуется. Опыт работы с...',
#   'responsibility': 'Разработка креативных концепций сайтов. Разработка дизайна на основе концепции. Создавать UX/UI для веб сервиса. Создание 2D и 3...'},
#  'contacts': None}

# %%
#Посморим на первые 5 названий вакансий
titles = [item['name'].lower() for item in vacs]
titles[:5]
# Out:
# ['web-дизайнер',
#  'дизайнер по доработке выпускных альбомов',
#  'директор it-управления',
#  'менеджер интернет-проектов / project manager',
#  'дизайнер по доработке выпускных альбомов']

# %%
#А теперь очень просто найдем самое часто встречаемое название вакансии

max(set(titles), key=titles.count)
# Out:
# 'программист 1с'

# %%
from collections import Counter
Counter(titles)
# Out:
# Counter({'web-дизайнер': 33,
#          'дизайнер по доработке выпускных альбомов': 5,
#          'директор it-управления': 1,
#          'менеджер интернет-проектов / project manager': 1,
#          'младший руководитель проектов': 1,
#          'программист 1с (2ая линия поддержки) [id15849]': 1,
#          'руководитель it проектов': 2,
#          'ведущий web-разработчик php/js (full stack)': 1,
#          'frontend developer (javascript, react)': 1,
#          'product owner': 8,
#          'руководитель проектов': 7,
#          'дизайнер ui/ux': 2,
#          'ведущий специалист поддержки систем 1с:еrp/ух [id21689/id19761]': 1,
#          'дизайнер ux/ui (проектировщик интерфейсов)': 1,
#          'разработчик java': 5,
#          'дизайнер ux/ui/web/mobile': 2,
#          'frontend-разработчик (react)': 9,
#          'web-дизайнер креативщик': 1,
#          'html-верстальщик / frontend программист': 1,
#          'интернет-маркетолог/сeo специалист': 1,
#          'руководитель it проекта в сфере жкх (разработка)': 1,
#          'руководитель отдела по работе с клиентами / account director/ руководитель отдела аккаунтинга': 1,
#          'программист php, html, bitrix': 2,
#          'дизайнер интерфейсов': 4,
#          'data-инженер/ разработчик dwh': 1,
#          'руководитель проекта / project manager': 2,
#          'java-разработчик (middle)': 1,
#          'начальник управления информационных технологий': 1,
#          'senior/middle frontend-разработчик (angular)': 1,
#          'php-программист': 16,
#          'senior .net developer/techlead': 1,
#          'разработчик php': 1,
#          'qa engineer (тестировщик)': 1,
#          'разработчик python': 5,
#          'разработчик python для проектов nlp/ ml': 1,
#          'frontend-разработчик (редакция "спорт-экспресс")': 1,
#          'frontend верстальщик / разработчик на react.js': 1,
#          'ui/ux designer': 2,
#          'php-программист (laravel)': 2,
#          'разработчик лендинга на wix': 1,
#          'php yii2 разработчик': 1,
#          'fullstack программист (php, javascript)': 1,
#          'менеджер по продукту': 1,
#          'тестировщик siebel crm [id16301]': 1,
#          'начинающий .net разработчик': 2,
#          'ведущий веб-дизайнер': 1,
#          'программист 1с': 62,
#          'ios разработчик': 17,
#          'проектировщик интерфейсов ux ui': 1,
#          'веб-дизайнер': 19,
#          'разработчик сайтов / дизайнер (с навыками web дизайна)': 2,
#          'руководитель портфеля проектов': 1,
#          'разработчик баз данных oracle': 1,
#          'с++ developer (maas)': 1,
#          'frontend developer': 7,
#          'разработчик frontend (react)': 1,
#          'front-end разработчик': 8,
#          'middle js/react developer': 1,
#          'ведущий web разработчик php': 1,
#          'программист "разработчик php 7, java script"': 1,
#          'менеджер проектов (разработка по)': 1,
#          'web-разработчик / программист php, html': 1,
#          'руководитель группы разработки/team leader': 1,
#          'ui-дизайнер': 1,
#          'продуктовый аналитик big data': 1,
#          'php программист': 2,
#          'javascript-разработчик (react.js)': 1,
#          'product manager (bu sport)': 1,
#          'frontend (react) разработчик': 4,
#          'программист .net': 2,
#          'web-дизайнер ui/ux': 1,
#          'программист php (laravel)': 1,
#          'программист 1c': 14,
#          'фронтенд react разработчик': 1,
#          'php-разработчик (junior)': 2,
#          'ui - дизайнер мобильных приложений': 1,
#          'руководитель/ менеджер направления по развитию финансовых продуктов и сервисов': 1,
#          'директор по информационным технологиям, cio': 1,
#          'frontend developer / разработчик reactjs': 1,
#          'руководитель по контролю за реализацией проектов в области it': 1,
#          'scrum master': 3,
#          'инженер - электронщик / асу тп / кипиа': 1,
#          'руководитель проекта (senior)': 1,
#          'владелец продукта / бизнес-аналитик/ product owner': 1,
#          'frontend-разработчик (javascript)': 1,
#          'руководитель продукта/ product onwer (проект efs)': 1,
#          'frontend разработчик (vue.js)': 2,
#          'c# разработчик': 1,
#          'it project manager': 4,
#          'javascript разработчик (react)': 2,
#          'delphi developer': 1,
#          'разработчик asp.net, c#': 1,
#          'frontend-разработчик': 39,
#          'project manager /менеджера проектов (it)': 1,
#          'разработчик интерфейсов (front-end разработчик)': 1,
#          'middle php-разработчик': 3,
#          'менеджер продукта "инструменты клиентского сервиса"': 1,
#          'php программист / web разработчик': 1,
#          'senior project manager': 1,
#          'дизайнер интерфейсов ui/ux (мобильная разработка)': 1,
#          'ios developer': 2,
#          'project manager (менеджер продукта)': 1,
#          'руководитель подразделения разработки': 1,
#          'программист dwh/bi': 1,
#          'программист-стажер 1c': 3,
#          'программист 1с-8': 1,
#          'frontend react developer': 1,
#          'руководитель проектов (по разработке по)': 1,
#          'scrum project manager': 1,
#          'web разработчик python / django': 1,
#          'frontend-разработчик (web, javascript, react)': 1,
#          'консультант 1с: зуп': 1,
#          '.net разработчик': 3,
#          'java-разработчик': 14,
#          'начинающий frontend разработчик': 1,
#          'ведущий инженер-разработчик (sdk-программист)': 1,
#          'python backend developer (middle)': 1,
#          'senior aws devops engineer': 1,
#          'разработчик sharepoint': 1,
#          'middle/ senior frontend-разработчик (angular)': 1,
#          'программист': 4,
#          'программист 1с (junior/middle)': 1,
#          'продуктовый дизайнер (ui/ux)': 1,
#          'начальник отдела 1 с': 1,
#          'веб-дизайнер ux/ui': 1,
#          'младший инженер по тестированию': 1,
#          'junior front-end разработчик': 3,
#          'php-разработчик': 18,
#          'ux-исследователь / ведущий ux-исследователь': 1,
#          'программист-преподаватель': 1,
#          'java developer (online banking)': 1,
#          'web-программист': 7,
#          'методолог 1с [id16467]': 1,
#          'руководитель проекта 1c\\руководитель ит': 1,
#          'html-верстальщик/ младший front-end разработчик': 1,
#          'менеджер стартап-проекта': 1,
#          'senior backend developer (php, laravel, remote)': 3,
#          'системный аналитик': 15,
#          'web-разработчик': 13,
#          'qa engineer (manual)': 2,
#          'project manager': 6,
#          'младший менеджер проекта / junior project manager': 1,
#          'frontend разработчик (junior)': 1,
#          'it project manager/ junior it project manager': 1,
#          'разработчик на react': 1,
#          'ux-проектировщик / дизайнер интерфейсов': 1,
#          'senior frontend developer': 2,
#          'разработчик c#': 6,
#          'ведущий c# разработчик': 1,
#          'enterprise architect': 1,
#          'лидер проектного и процессного управления': 1,
#          'software developer in test': 1,
#          'product designer': 1,
#          'senior python developer': 5,
#          'devops specialist': 1,
#          'главный инженер разработки (платформа 1с)': 1,
#          'qa engineer (ручное тестирование)': 1,
#          'unity разработчик': 1,
#          'старший консультант sap bw': 1,
#          'с#-разработчик (проект на .net core)': 1,
#          'senior/middle frontend-разработчик': 1,
#          'full stack программист': 1,
#          'devops инженер': 3,
#          'руководитель отдела поддержки и внедрения по на платформе 1с:erp': 1,
#          'product owner финтех (big data)': 1,
#          'руководитель проекта по автоматизации бизнес-процессов': 1,
#          "product owner дивизион 'особенные решения'": 1,
#          'верстальщик (middle)': 1,
#          'руководитель проектного офиса (project manager)': 1,
#          'специалист по it': 6,
#          'product manager': 5,
#          'pr-директор': 1,
#          'контент-менеджер': 2,
#          'руководитель проектов bitrix24/project manager': 1,
#          'java-разработчик (backend)': 1,
#          'python developer': 4,
#          'backend-разработчик (python,\xa0django)': 1,
#          'системный администратор': 3,
#          'инженер по ремонту оргтехники': 1,
#          'ведущий инженер-разработчик лкм': 1,
#          'ведущий программист 1с': 4,
#          'разработчик фронтэнда': 2,
#          'директор по информационным технологиям (ит директор)': 1,
#          'веб-программист': 4,
#          'стажер/программист 1с': 1,
#          'программист 1с (erp)': 1,
#          'системный администратор (начинающий)': 1,
#          'программист php backend developer / laravel': 1,
#          'тестировщик-автоматизатор (java)': 1,
#          'главный специалист по внедрению ит- процессов': 1,
#          'project manager/менеджер it проектов': 1,
#          'frontend developer (react/redux)': 1,
#          'программист php': 9,
#          'бизнес-аналитик 1с (ут)': 1,
#          'frontend-разработчик (+вёрстка )': 1,
#          'дизайнер игр': 1,
#          'стажер 1с': 1,
#          'java разработчик/java developer': 1,
#          'фронтенд-разработчик': 1,
#          'frontend developer / react': 1,
#          'frontend разработчик': 8,
#          'it-специалист в управление финансовой отчетности': 1,
#          'product manager / руководитель продукта': 1,
#          'менеджер проектов (техническая поддержка сайтов)': 1,
#          'интернет маркетолог / web-мастер': 1,
#          'senior full-stack developer (php+jquery)': 2,
#          'html-верстальщик': 3,
#          'гейм-дизайнер': 1,
#          'младший разработчик oracle': 1,
#          'директор службы управления бизнес-решениями': 1,
#          'руководитель проектов 1с': 1,
#          'devops-инженер': 2,
#          'senior php разработчик': 2,
#          'главный архитектор приложений': 1,
#          'программист c#': 3,
#          'technology scout': 1,
#          'разработчик rpa': 1,
#          'it-директор (cio) в міжнародну компанію': 1,
#          'начальник отдела технической поддержки арм': 1,
#          'lead ui/ux дизайнер': 1,
#          'project manager / менеджер it проекта': 1,
#          'frontend web developer (vue.js)': 1,
#          'php-программист (yii2)': 1,
#          'java разработчик': 5,
#          'веб-разработчик': 4,
#          '.net разработчик в команду ecm': 1,
#          'senior php developer': 2,
#          'инженер-установщик по': 1,
#          '1с программист': 1,
#          'заместитель начальника управления методологии и анализа кредитных рисков (pd, lgd)': 1,
#          'frontend developer vuejs (sovcombank it)': 1,
#          'java-разработчик в команду r-online': 1,
#          'nodejs разработчик': 1,
#          'разработчик react/redux': 1,
#          'стажер 1с (технический специалист / сервис-инженер 1с)': 1,
#          'менеджер продукта (портал)': 1,
#          'vue.js разработчик': 1,
#          'java-backend разработчик': 2,
#          'программист 1с (оперативный учет)': 1,
#          'frontend-разработчик (angular)': 1,
#          'middle backend/full stack developer': 1,
#          'php разработчик': 1,
#          'технический руководитель проекта (веб-проект)': 1,
#          'стажёр в digital-агентство': 1,
#          'дизайнер видео-контента': 1,
#          'data scientist': 4,
#          'разработчик vue js (м.бауманская)': 1,
#          'программист 1c 8': 2,
#          'продакт-менеджер bi': 1,
#          'junior project manager': 1,
#          'frontend developer (vue.js)': 1,
#          'react developer': 1,
#          'бизнес-аналитик': 5,
#          'hr business partner': 1,
#          'ux\\ui дизайнер': 1,
#          'junior qa / специалист по технической поддержке': 1,
#          'верстальщик': 2,
#          'ux/ui дизайнер': 5,
#          'руководитель отдела маркетинга в интернет-проекте': 1,
#          'менеджер продукта': 1,
#          'инженер-программист': 9,
#          'бухгалтер консультант 1с': 1,
#          'стажер web-разработчик/программист': 1,
#          'руководитель отдела развития бизнеса': 1,
#          'руководитель филиала it компании( b2b сегмент)': 1,
#          'с# developer': 1,
#          'мастер bootcamp': 1,
#          'enterprise архитектор': 1,
#          'backend-разработчик .net core (senior/middle)': 1,
#          'юрисконсульт': 1,
#          'frontend разработчик / javascript разработчик': 1,
#          'project manager (digital)': 1,
#          'руководитель направления развития фронт-офисных систем/руководитель разработки': 1,
#          'менеджер проекта (интернет-магазин)': 1,
#          'технический писатель/специалист по написанию технической документации (технических заданий)': 1,
#          'devops-инженер в группу разработки инструментов обеспечения качества': 1,
#          'тестировщик web-приложений': 1,
#          'разработчик ms sql': 2,
#          'сборщик компьютеров': 1,
#          'инженер-программист микроконтроллеров': 1,
#          'ios software developer': 1,
#          'frontend js developer': 1,
#          'программист (front-end web-разработчик на vue.js)': 1,
#          'главный специалист по сопровождению сэд docs vision и сэд тезис': 1,
#          'разработчик 1с': 5,
#          'программист javascript и с#': 1,
#          'ведущий разработчик java': 1,
#          'ведущий разработчик php': 1,
#          'программист php/разработчик битрикс (bitrix)': 1,
#          'product owner/менеджер продукта (фaкторинг)': 1,
#          'javascript / frontend / react developer': 1,
#          'инженер в help desk': 1,
#          'стажер-программист 1с': 5,
#          'html-верстальщик / junior-frontend': 1,
#          'руководитель it-проектов': 2,
#          'ведущий программист 1c erp': 1,
#          'software tester': 1,
#          'программист 1с crm': 1,
#          'senior frontend developer (vue.js)': 1,
#          'программист-разработчик java/ java- script': 1,
#          'middle/senior front-end developer (reactjs)': 1,
#          'fullstack developer (java spring+js vue.js)': 1,
#          'middle/senior frontend developer (js, react)': 1,
#          'full stack разработчик': 3,
#          'nodejs back-end разработчик': 1,
#          'middle php developer': 3,
#          'главный специалист кадровых систем (зуп)': 1,
#          'php developer (laravel)': 1,
#          'ведущий инженер-программист (.net, js)': 1,
#          'junior/middle front-end developer': 1,
#          'ios developer (new project)': 1,
#          'менеджер проектов внедрения по': 1,
#          'руководитель отдела продаж': 3,
#          'младший разработчик pl/sql': 1,
#          'php-разработчик (senior)': 1,
#          'ведущий php-разработчик (symfony)': 1,
#          'delivery manager': 2,
#          'начинающий python backend разработчик': 1,
#          'контент-менеджер / веб-мастер': 1,
#          'руководитель проектов по развитию услуги мониторинга устройств самообслуживания': 1,
#          'аналитик': 2,
#          'data engineer (sql)': 1,
#          'java разработчик (junior/middle)': 1,
#          'php developer / php разработчик (middle)': 1,
#          'html/php - разработчик': 1,
#          'руководитель проектов внедрений': 1,
#          'frontend developer (vue.js, node.js)': 1,
#          'frontend специалист': 1,
#          'frontend-разработчик middle+': 1,
#          'инженер по тестированию (санкт-петербург)': 1,
#          'senior business analyst / product manager': 1,
#          'ведущий инженер-программист микроконтроллеров': 1,
#          'ведущий архитектор bss/oss': 1,
#          'frontend-разработчик (confluence, react)': 2,
#          'руководитель направления технологий операционных процессов (rpa)': 1,
#          'backend разработчик (c#)': 1,
#          'java-разработчик в команду инвестиций': 1,
#          'преподаватель python & data science': 1,
#          'ит-специалист дивизиона "центрального казахстана"': 1,
#          'директолог': 1,
#          'разработчик ui5': 1,
#          'middle/senior .net разработчик': 1,
#          'разработчик .net': 2,
#          'менеджер проектов (со знанием seo)': 1,
#          'back-end developer python': 1,
#          'специалист по тестированию в 1с/тестировщик': 1,
#          'специалист по анализу данных ( sql)': 1,
#          'аналитик (москва)': 1,
#          'руководитель проекта по созданию лк в устройствах самообслуживания': 1,
#          'программист с#/ mssql': 1,
#          'руководитель программы юридических ит-разработок': 1,
#          'руководитель направления crm': 1,
#          'java developer for cln': 2,
#          'junior разработчик c#': 1,
#          'веб-дизайнер ui/ux': 1,
#          'middle developer .net/c#': 1,
#          'front end developer (react)': 1,
#          'скриптер ue4 (blueprint)': 1,
#          'javascript разработчик': 3,
#          'программист-стажер 1с': 3,
#          'программист delphi': 2,
#          'руководитель отдела продаж (it-сфера)': 1,
#          'javascript developer': 1,
#          'java backend разработчик': 1,
#          'руководитель управления аналитики': 1,
#          'project coordinator': 1,
#          'разработчик-консультант ibm cognos planning': 1,
#          'lead frontend-разработчик (react)': 1,
#          'regular react developer / программист': 1,
#          'программист-разработчик': 3,
#          'senior t-sql developer': 1,
#          'разработчик': 3,
#          'backend разработчик (java)': 1,
#          'senior/lead php developer': 1,
#          'fullstack developer (vue.js, node.js)': 1,
#          'web-разработчик js/react (front end)': 1,
#          'junior data analyst': 1,
#          'delivery lead': 1,
#          'главный программист 1с:erp и 1с:бп': 1,
#          'начальник управления opsteam': 1,
#          'seo оптимизатор': 1,
#          '1с консультант-аналитик': 1,
#          'junior developer ios / android (software maintenance)': 1,
#          'специалист по тестированию (qa)': 1,
#          'frontend разработчик (react.js)': 1,
#          "администратор трайба (в команду штаба трайба 'массовая персонализация')": 1,
#          'бизнес-аналитик (1с)': 1,
#          'аналітик в головний офіс / стажер': 1,
#          'руководитель проектов / ит-менеджер': 1,
#          'ведущий специалист по информационным технологиям': 1,
#          'middle product manager (pm) for nissan digital': 1,
#          'frontend developer react.js': 1,
#          'golang программист': 1,
#          'ведущего инженера-программист c# .net/ full stack developer .net': 1,
#          'ведущий программист': 1,
#          'engineer for image processing': 1,
#          'python разработчик': 4,
#          'php developer': 2,
#          'старший проектный менеджер': 1,
#          'бэкенд разработчик django rest framework': 1,
#          'junior frontend разработчик': 1,
#          'middle react developer': 1,
#          'системный аналитик (асуз)': 1,
#          'android developer': 2,
#          'product owner (команда face recognition)': 1,
#          'дизайнер мобильных приложений / web-дизайнер': 1,
#          'backend java / kotlin': 1,
#          'web developer (wordpress)': 2,
#          'junior it рекрутер': 1,
#          'react.js developer': 1,
#          'архитектор по технической инфраструктуре': 1,
#          'project manager (ecommerce)': 1,
#          'junior qa инженер': 1,
#          'ведущий программист c#': 1,
#          'data scientist/ директор в управлении розничного моделирования': 1,
#          'full stack web developer vue, python': 1,
#          'middle / senior js-разработчик': 1,
#          'python/sas developer': 1,
#          'python middle developer': 1,
#          'java software engineer': 1,
#          'ит-специалист': 2,
#          'разработчик crm': 2,
#          'преподаватель (программирование / информационные технологии)': 1,
#          'devops developer': 1,
#          'android-developer': 1,
#          'системный архитектор': 2,
#          'ведущий javascript разработчик/team lead (vue.js)': 1,
#          'web-программист по 1с bitrix': 1,
#          'senior ios developer': 2,
#          '1с разработчик (ук "открытие")': 1,
#          'инженер-программист 1c по учетным системам': 1,
#          'fullstack middle developer (php)': 1,
#          'senior frontend разработчик (в команду lending)': 1,
#          'frontend-разработчик (angularjs)': 1,
#          'разработчик ios (buyerx/advertisement)': 1,
#          'разработчик с#': 2,
#          'middle/senior .net sde': 2,
#          '1с консультант / разработчик': 1,
#          'senior java developer (cpdm)': 1,
#          'разработчик sharepoint online': 1,
#          'senior front end (react) developer': 1,
#          'преподаватель/тренер курса "java enterprise edition"': 1,
#          'ведущий веб-разработчик': 1,
#          'инженер-программист ( java разработка )': 1,
#          'разработчик на c++ под linux': 1,
#          'senior data engineer (teradata/greenplum).': 1,
#          'главный специалист (webtutor)': 1,
#          'инженер-программист labview': 2,
#          'full-stack разработчик .net, c#, angular (senior)': 1,
#          'software development engineer in test (python)': 1,
#          'ведущий разработчик': 1,
#          'junior 1c программіст': 1,
#          'программист-разработчик hcl (ibm/lotus) notes domino': 1,
#          'scala developer': 3,
#          'senior backend developer': 1,
#          'golang developer (development tools engineer)': 1,
#          'abap-разработчик': 1,
#          'менеджер проектов (анализ и автоматизация отчетности)': 1,
#          'ресечер it': 1,
#          'практикант - аналитик': 1,
#          'java-программист': 2,
#          'руководитель учебного отдела': 1,
#          'middle python developer': 1,
#          'php backend разработчик': 1,
#          'администратор сайта 1с битрикс': 1,
#          'инженер по тестированию (qa support engineer/junior)': 1,
#          'бизнес-аналитик crm (bpm online)': 1,
#          'веб-программист (wordpress)': 1,
#          'функциональный архитектор': 2,
#          'senior front-end developer': 3,
#          'инженер отдела производственно-конструкторской документации': 1,
#          'senior full stack developer (php / javascript)': 1,
#          'frontend-разработчик (vuejs)': 1,
#          'старший программист 1с': 3,
#          'веб-разработчик (php full-stack) / middle php / javascript / mysql / css / html': 1,
#          'руководитель центра компетенций системного анализа': 1,
#          'product owner (trade finance)': 1,
#          'ui/ux дизайнер': 5,
#          'верстальщик html / front-end разработчик': 1,
#          'стажер sap hr': 1,
#          'разработчик c# .net': 1,
#          'менеджер\xa0 по автоматизации и оптимизации бизнес процессов \xa0в mass personalization': 1,
#          'начальник отдела развития компетенций пользователей (it-направление)': 1,
#          'middle php программист/web -разработчик': 1,
#          'java разработчик (senior/middle)': 1,
#          'product owner (brokers integration)': 1,
#          'программист 1с (интернет-магазин)': 1,
#          'senior java developer': 6,
#          'frontend-разработчик (javascript и typescript)': 1,
#          'разработчик node.js': 2,
#          'инженер-программист data science, computer vision (middle)': 1,
#          'старший математик-программист': 1,
#          'главный специалист/ менеджер регионального центра обработки информации': 1,
#          'php программист (yii2)': 1,
#          'программист sql / специалист по реализации отчетных форм': 1,
#          'c/c++ разработчик': 1,
#          'стажер-разработчик javascript': 1,
#          'программист с++': 4,
#          'frontend-разработчик (программист javascript, vue.js)': 1,
#          'системный аналитик (система процессинга e-commerce заказов компании)': 1,
#          'python программист': 1,
#          'инженер-электронщик': 1,
#          'web-разработчик wordpress': 1,
#          'frontend-программист/верстальщик': 1,
#          'ui/ux-дизайнер': 1,
#          'junior developer wordpress': 1,
#          'php-разработчик/программист (bitrix)': 1,
#          'разработчик javascript react (middle / junior)': 1,
#          'project-менеджер': 1,
#          'проектировщик-разработчик/программист 1с решений для бухгалтерского учета': 1,
#          'архитектор /аналитик': 1,
#          'php-программист/web-программист/fullstack-разработчик': 1,
#          'директор по информационным технологиям (в п. ванино хабаровский край)': 1,
#          'руководитель проекта 1c': 1,
#          'методист по эдо с контролирующими органами': 1,
#          'архитектор по учету затрат и расчету себестоимости (sap co)': 1,
#          'разработчик full-stack (python, angular)': 1,
#          'консультант по navision': 1,
#          'middle front-end разработчик': 1,
#          'программист net/java': 1,
#          'разработчик мобильных приложений': 1,
#          'php software developer (junior / middle)': 1,
#          'программист-консультант 1c': 2,
#          'с++ client developer': 1,
#          'ведущий разработчик (web, .net, full-stack)': 1,
#          'asp.net specialist (backend/full stack)': 1,
#          'тестировщик по / qa engineer': 2,
#          'ведущий php-разработчик': 2,
#          'backend java-разработчик': 1,
#          'специалист по технической защите информации (006)': 1,
#          'frontend - разработчик': 2,
#          'devops engineer': 3,
#          'руководитель проектов/менеджер crm': 1,
#          'программист php битрикс': 1,
#          'ruby on rails разработчик': 1,
#          'frontend-разработчик/ведущий frontend разработчик - группа разработки цифровых продуктов': 1,
#          'ведущий продуктовый дизайнер ux/ui': 1,
#          'ведущий аналитик': 1,
#          'руководитель разработки/team lead': 1,
#          'web-дизайнер ux/ui': 1,
#          'руководитель отдела интернет вещей (стрим лидер iot)': 1,
#          'младший программист java': 1,
#          'руководитель ит-проектов': 1,
#          'ux/ui дизайнер в hr-продукт': 1,
#          'product manager vscale': 2,
#          'специалист сопровождения систем 1с ( 2 категории)': 1,
#          'full stack android developer': 1,
#          'data engineer': 2,
#          'младший системный администратор / специалист отдела информационных технологий': 1,
#          'техник-программист': 2,
#          'тимлид oracle pl/sql': 1,
#          'ассистент руководителя (лаборатория клиентского опыта)': 1,
#          'ux/ui designer': 1,
#          'бизнес-аналитик ит проектов': 1,
#          'специалист центра технического обслуживания (цто) клиентов': 1,
#          'программист python': 2,
#          'главный специалист отдела информационных технологий': 1,
#          'аналитик портфельного менеджмента crm и кампаний продаж (корпоративный блок)': 1,
#          'инженер-программист i категории (backend php разработчик)': 1,
#          'разработчик сайта': 1,
#          'программист java': 5,
#          'руководитель направления по эксплуатации автоматизированной системы расчетов (программа базис)': 1,
#          'разработчик fullstack': 1,
#          'ios разработчик (приложение мобильный банк)': 1,
#          'react native разработчик': 2,
#          'руководитель проектов внедрения и сопровождения': 1,
#          'junior devops/младший системный администратор (sre)': 1,
#          'руководитель проекта (middle)': 1,
#          'дизайнер (web-дизайнер)': 1,
#          'стажер-разработчик java': 1,
#          'веб-дизайнер (работа в офисе)': 1,
#          'junior vue.js frontend developer': 1,
#          'администратор проектов it': 1,
#          'front-end developer (vue.js)': 1,
#          'директор по ит': 1,
#          'аналитик ( команда интеграции продуктов экосистемы)': 1,
#          'главный инженер python': 1,
#          'разработчик программного обеспечения для микроконтроллеров (инженер-программист)': 1,
#          'senior python 3.x developer': 1,
#          'преподаватель it-дисциплин': 1,
#          'программист 1с: бухгалтерия 8 (версия корп)': 1,
#          'fullstack (ai)': 1,
#          'java developer': 4,
#          'it problem manager': 1,
#          'аналитик - программист с#': 1,
#          'senior frontend developer (react)': 4,
#          'аналитик по внедрению и сопровождению банковского программного обеспечения (ташкент)': 1,
#          'руководитель службы технологий операционных процессов (rpa)': 1,
#          'java-разработчик реестра api (meta)': 1,
#          'менеджер it-продаж': 1,
#          'разработчик фронтэнда (vue.js)': 1,
#          'full stack .net developer': 1,
#          'преподаватель курсов "разработка ios приложений на swift"': 1,
#          'разработчик etl-движка': 1,
#          'js developer (middle)': 1,
#          'web-разработчик (python/reactjs)': 1,
#          'java разработчик (интеграция / mulesoft)': 1,
#          'разработчик интерфейсов': 1,
#          'аналитик внедрения': 1,
#          'старший frontend разработчик': 1,
#          'программист встраиваемых систем (микроконтроллеров)': 1,
#          'full-stack разработчик (c#, mssql, js)': 1,
#          'технический консультант linux (devops )': 1,
#          'системный архитектор 1с / team leader': 1,
#          'back-end разработчик (nodejs)': 1,
#          'qa engineer': 2,
#          'middle php-разработчик (удаленно)': 1,
#          'руководитель направления по развитию ит': 1,
#          'ux designer': 1,
#          'frontend разработчик (js)': 1,
#          'руководитель команды разработки продукта "безопасный платеж"': 1,
#          "юрист дивизион 'особенные решения'": 1,
#          'frontend разработчик (js/react)': 1,
#          'инженер по сопровождению проектов "умный дом"': 1,
#          'php программист (fullstack)': 1,
#          'junior php developer / младший php программист': 1,
#          'тестировщик по': 2,
#          'веб-разработчик frontend (react)': 2,
#          'sql developer': 1,
#          'программист (c#\\ asp.net\\mvc)': 1,
#          'customer journey expert (cje)': 1,
#          'программист с#': 1,
#          'ведущий аналитик bi': 1,
#          'junior java developer': 1,
#          'javаscript-разработчик (frontend)': 1,
#          'руководитель ит проектов (erp системы) [id41521]': 1,
#          'java разработчик. проект дбо 2.1': 1,
#          'главный специалист по информационной безопасности направления «экспертиза» [id19542]': 1,
#          'senior frontend разработчик (react.js)': 1,
#          'программист-разработчик django': 1,
#          'технический руководитель юнита (messenger)': 1,
#          'разработчик bi': 2,
#          'инженер-программист асу тп': 2,
#          'аналитик технической поддержки': 1,
#          'интернет-маркетолог': 1,
#          'frontend-разработчик (проекты data science)': 1,
#          'backend разработчик (php)': 1,
#          'java developer (высоконагруженные системы)': 1,
#          'инженер-программист embedded linux': 1,
#          'java разработчик (middle/senior) - проект ксо': 1,
#          'ux / ui дизайнер': 1,
#          'business analyst': 1,
#          'seo специалист (продвижение сайта)': 1,
#          'frontend javascript developer': 1,
#          'разработчик битрикс': 1,
#          'бизнес-аналитик / ba': 1,
#          'backend developer python': 1,
#          'разработчик программного обеспечения 1с управление холдингом': 1,
#          'junior backend developer': 1,
#          'руководитель по развитию продуктов (iot)': 1,
#          'начальник отдела аналитики некредитного направления / senior analyst (департамент розничного crm)': 1,
#          'главный аналитик по обработке сведений': 1,
#          'бизнес аналитик / системный аналитик ит проектов ( axapta, 1c)': 1,
#          'директор ит / начальник отдела 1с-разработок (белореченск)': 1,
#          'php developer (middle, senior)': 1,
#          'backend разработчик': 3,
#          'старший инженер-системотехник': 1,
#          'c# (.net) разработчик': 1,
#          'tech lead с# разработчик (asp.net core)': 1,
#          'web-разработчик (cms bitrix)': 1,
#          'разработчик ruby, ruby on rails': 1,
#          'разработчик php (full stack)': 1,
#          'web-разработчик / программист php': 1,
#          'front-end developer (middle/senior)': 1,
#          'data engineer/dwh (рекламные технологии)': 1,
#          'программист битрикс / full-stack разработчик': 1,
#          'руководитель проектов по разработке и внедрению по': 1,
#          'руководитель проекта (отдел технологий телекоммуникаций)': 1,
#          'web-программист (php)': 2,
#          'java - разработчик': 1,
#          'ведущий специалист/аналитик опгп': 1,
#          'менеджер по проектам': 1,
#          'инженер по тестированию/qa': 1,
#          'product owner (it)': 1,
#          'frontend-разработчик (verticals)': 1,
#          'frontend developer (react) - middle/senior': 1,
#          'front-end developer/ фронтенд разработчик': 1,
#          'бизнес-аналитик / системный аналитик': 1,
#          'javascript программист': 1,
#          'инженер нагрузочного тестирования': 1,
#          'android разработчик': 1,
#          'разработчик отчетных форм (sql)': 1,
#          'middle .net developer': 2,
#          'гип/архитектор проекта': 1,
#          'специалист сопровождения систем 1с (1 категории)': 1,
#          'ведущий специалист по аналитике': 1,
#          'руководитель проекта/функциональный архитектор 1с:erp': 1,
#          'junior вack-end developer (php) программист': 1,
#          'middle/senior frontend javascript developer (vue.js)': 1,
#          'frontend-разработчик в тинькофф журнал': 1,
#          'cистемный администратор': 1,
#          'инженер-конструктор': 1,
#          'junior web developer/разработчик бизнес решений (php, javascript, c#)': 1,
#          'ведущий разработчик postgresql/ team lead': 1,
#          'дизайнер': 3,
#          'инженер техподдержки/support (английский язык)': 1,
#          'business analyst - sap (fi) group - consulting department': 1,
#          'ведущий web разработчик (angular +.net core)': 1,
#          'разработчик бд': 1,
#          'начальник отдела развития дистанционных каналов корпоративного бизнеса': 1,
#          'web-программист (php, javascript, верстка)': 1,
#          'ui / ux дизайнер': 1,
#          'технический писатель': 1,
#          'junior frontend developer': 1,
#          'junior java-разработчик': 1,
#          'младший программист php (junior)': 2,
#          'web-дизайнер / ux-специалист': 1,
#          'java разработчик (spring, postgre)': 1,
#          'главный аналитик (отдел технологий по расчетным сервисам)': 1,
#          'инженер по разработке по 2 категории': 1,
#          'product it manager': 1,
#          'frontend developer (vue)': 1,
#          'php-программист (стажер php-программист)': 1,
#          'начинающий программист (стажер) разработчик .net, c#, css, html': 1,
#          'frontend разработчик reactjs': 1,
#          'android-разработчик (удаленно)': 1,
#          'frontend-разработчик (vue.js)': 3,
#          'frontend-разработчик (middle/junior)': 1,
#          'руководитель продукта': 1,
#          'инженер-тестировщик телекоммуникационного оборудования и по': 1,
#          'программист 1c 8.3': 1,
#          'python developer (junior)': 1,
#          'pr менеджер': 1,
#          'директор отдела разработки': 1,
#          'intern business analyst': 1,
#          'ученик программиста 1с (junior- программист)': 1,
#          'unity developer': 1,
#          'менеджер направления отдела аудита информационных технологий': 1,
#          'seo-оптимизатор (seo-специалист)': 1,
#          'руководитель проектов разработки информационных систем': 1,
#          'руководитель проектной группы (it)': 1,
#          'ит-специалист (специалист технической поддержки)': 1,
#          'front-end разработчик (vue.js)': 1,
#          'разработчик python/django': 1,
#          'проектировщик/дизайнер интерфейсов ux/ui': 1,
#          'php разработчик (junior/middle)': 1,
#          'специалист по технической поддержке (i)': 1,
#          'junior/middle qa-engineer': 1,
#          'программист 1с erp': 1,
#          'senior manual test engineer (ukraine)': 1,
#          'разработчик java, react, postgresql': 1,
#          'инженер-программист 1с': 1,
#          'security leader sdlc': 1,
#          'разработчик\u200e ruby on rails': 1,
#          'программист с++/qt': 1,
#          'разработчик обмена данными': 1,
#          'data engineer (прк)': 1,
#          'разработчик lotus notes/ developer lotus notes': 1,
#          'инженер - программист с, с++, с# (красное село)': 1,
#          'android разработчик - безопасность': 1,
#          'разработчик react js (м. динамо)': 1,
#          'ведущий java-разработчик/senior java developer': 1,
#          'senior unity/ui\xa0developer': 1,
#          'middle java developer': 2,
#          'преподаватель авторизованных курсов microsoft ( sql server, powershell, bi)': 1,
#          'ведущий php-разработчик (senior php developer)': 1,
#          'team lead / java backend developer (омниканальная платформа)': 1,
#          'middle python разработчик (go)': 1,
#          'ведущий разработчик/ teamlead': 1,
#          'js developer (angular 6+)': 1,
#          'ведущий java-разработчик (сеть)': 1,
#          'специалист 1с (практика разработки прикладных информационных систем)': 1,
#          'специалист (консультант) sap fi, co, aa': 1,
#          'middle/senior front-end developer (react)': 1,
#          'middle ios developer': 1,
#          'старший инженер-разработчик (c, matlab)': 1,
#          "ведущий программист terrasoft creatio (bpm'online)": 1,
#          'php-программист (бэкенд-разработчик битрикс)': 1,
#          'web-разработчик php': 1,
#          'java expert': 1,
#          'middle .net developer (asp mcv)': 1,
#          'c# developer': 1,
#          'ai sensors algorithms engineer (dsp)': 2,
#          'backend developer': 1,
#          'lead site reliability engineer (lead sre)': 1,
#          'senior/lead java-разработчик': 1,
#          'qa engineer (ведущий тестировщик по)': 1,
#          'аккаунт-менеджер / менеджер по работе с клиентами': 1,
#          'программист sql': 3,
#          'менеджер по развитию бизнеса': 1,
#          'тестировщик (qa)': 2,
#          'senior kotlin software developer': 1,
#          'senior javascript developer (react)': 1,
#          'php middle разработчик': 1,
#          'senior engineer (sre & observability)': 1,
#          'системный программист linux': 1,
#          'системный аналитик erp': 1,
#          'php team lead в delivery-club': 1,
#          'ведущий программист php (senior)': 1,
#          'администратор 1с': 1,
#          'старший разработчик-исследователь (ai)': 1,
#          'директор департамента 1с': 3,
#          'старший/ведущий консультант 1с': 1,
#          'инженер сопровождения по': 1,
#          'ведущий специалист sap pm (topo)': 1,
#          'старший разработчик php': 1,
#          'аналитик-программист 1с': 1,
#          'frontend разработчик, cs': 1,
#          'java разработчик (интеллектуальная система управления)': 1,
#          'devops engineer (api management system)': 1,
#          'инженер-программист с++ (web-сервис)': 1,
#          '1с-разработчик': 1,
#          'ведущий инженер по тестированию/qa lead': 1,
#          'системный аналитик (разработка по)': 2,
#          'team lead java developoer / главный разработчик': 1,
#          'fullstack разработчик python (sc-1)': 1,
#          'разработчик платформы рекомендательных систем. data engineer.': 1,
#          'главный специалист (методология качества данных хд)': 1,
#          'разработчик sql': 2,
#          'middle js/react native developer': 1,
#          'разработчик crm (dynamics)': 1,
#          'senior frontend engineer': 1,
#          'специалист по внедрению и сопровождению по 3d civil': 1,
#          'php / javascript разработчик': 1,
#          'разработчик программного обеспечения и баз данных': 2,
#          'разработчик бд (postgresql /oracle)': 1,
#          'системный аналитик/технический писатель': 1,
#          'fullstack разработчик на python': 1,
#          'главный программист 1с': 1,
#          'unity с# developer': 1,
#          'системный аналитик (финансовые системы)': 1,
#          'специалист по управлению ит-активами / it asset management specialist': 1,
#          'младший программист php': 1,
#          'qa automation engineer': 1,
#          'аналитик siebel crm [id16302]': 1,
#          'android developer (team lead)': 1,
#          'преподаватель/тренер по курсу: создание запросов power query в ms excel и power bi. практикум': 1,
#          'программист в отдел разработки': 1,
#          'главный специалист (rpa) службы технологий операционных процессов': 1,
#          'менеджер crm в массовую персонализацию': 1,
#          'блокчейн разработчик (интеграции)': 1,
#          'web-developer': 1,
#          'etl-bigdata developer': 1,
#          'аналитик кис ттд': 1,
#          'java разработчик [id21114]': 1,
#          'менеджер продукта / product manager (product owner) в г. москва': 1,
#          'администратор субд / dba (posgresql)': 1,
#          'python-разработчик': 1,
#          'javascript-разработчик (react)': 1,
#          'middle frontend developer (marketplace)': 1,
#          'программист / разработчик revit (bim разработчик)': 1,
#          'разработчик android': 1,
#          'разработчик баз данных (c#, t-sql)': 1,
#          'engagement manager': 1,
#          'ведущий программист 1c': 2,
#          'serialization specialist (pharma)': 1,
#          'full-stack js/python разработчик': 1,
#          'java developer (java ee)': 1,
#          'c#/.net core developer': 1,
#          'delphi разработчик': 1,
#          'инженер-программист (.net, js)': 1,
#          'malware analyst for imunify security': 1,
#          'teamlead devops': 1,
#          'программист битрикс': 1,
#          'php разработчик (битрикс24)': 1,
#          'frontend developer (middle/senior)': 1,
#          'системный аналитик / системный архитектор': 1,
#          'разработчик по (цфт-банк, продукт- обязательная отчетность)': 1,
#          'senior network planning and optimization engineer': 1,
#          'ведущий java-разработчик': 1,
#          'начальник отдела информационных систем и программного обеспечения': 1,
#          'программист 1с ут (удалённо)': 1,
#          'руководитель проекта/ project manager': 1,
#          'младший инженер по обеспечению качества (qa engineer)': 1,
#          'full stack разработчик asp.net core/angular': 1,
#          'инженер-программист c++ (qt)': 1,
#          'ведущий программист 1с erp': 1,
#          'инженер отдела информационных технологий (сопровождение программных продуктов)': 1,
#          'back-end разработчик (php)': 2,
#          'scrum мастер': 1,
#          'ведущий разработчик c/c++': 1,
#          'it recruter': 1,
#          'python разработчик (middle backend software engineer)': 1,
#          'программист bitrix (junior)': 1,
#          'разработчик / data engineer (big data)': 1,
#          'senior .net developer (финтех, антифрод)': 1,
#          'etl developer': 1,
#          'fullstack разработчик': 1,
#          'qa engeneer (python)': 1,
#          'контент-менеджер (веб-мастер)': 1,
#          'стажер/младший разработчик (dwh/etl, big data)': 1,
#          'golang разработчик': 1,
#          'аналитик по внедрению систем для риск-менеджмента': 1,
#          'разработчик javascript/react': 1,
#          'it-менеджер': 1,
#          'frontend\xa0- разработчик (react)': 1,
#          'developer с++': 1,
#          'системный аналитик в контур.меркурий': 1,
#          '3d моделлер/3d художник': 1,
#          'преподаватель (web-разработка, full-stack)': 1,
#          'разработчик поискового ядра c++': 1,
#          'программист/ web-разработчик': 1,
#          'php-разработчик yii (middle)': 1,
#          'системный администратор - инженер по внедрению и поддержке unix-систем': 1,
#          'react native developer': 1,
#          'программист t-sql': 1,
#          '3d artist / 3d художник': 1,
#          'frontend разработчик (react)': 2,
#          'php developer (billing team)': 1,
#          'devops expert - cloud software development': 1,
#          'разработчик/программист с#': 1,
#          'middle data science в r&d': 1,
#          'full-stack разработчик / web разработчик': 1,
#          'разработчик frontend (react native), группа улучшения бизнес-технологий и ит (#eytechnology)': 1,
#          'программист perl': 1,
#          'kotlin/java-программист': 1,
#          'ai research engineer [computer vision, machine learning, algorithms]': 1,
#          'разработчик бд (медицинская информационная система)': 1,
#          'менеджер по работе с клиентами (программные продукты 1с)': 1,
#          'руководитель проекта ecommerce': 1,
#          'инженер по тестированию': 2,
#          'инженер микроэлектроники': 1,
#          'ведущий разработчик базы данных (postgresql)': 1,
#          'преподаватель it (компьютерных курсов, программирования, информатики)': 1,
#          'java-junior разработчик (дбо по аккредитивам юл)': 1,
#          'senior / middle .net developer': 1,
#          'ведущий разработчик с#': 1,
#          'java-разработчик (корпоративные приложения)': 1,
#          'ux/ui дизайнер (мобильное приложение)': 1,
#          'php developer (backend / frontend)': 1,
#          'битрикс-программист': 1,
#          'product owner/голосовой ассистент в ivr': 1,
#          'инженер-тестировщик': 1,
#          'менеджер услуги \\ service desk manager': 1,
#          'python junior - разработчик': 1,
#          'full-stack php разработчик / vpn сервис': 1,
#          'инженер по тестированию по / qa engineer': 1,
#          'android-разработчик': 3,
#          'java developer (россия)': 1,
#          'системный аналитик (b2c, e-com web and mobile)': 1,
#          'frontend game developer': 1,
#          'бизнес-аналитик по направлению развития платформы интернета вещей': 1,
#          '1с - программист в международный холдинг': 1,
#          'junior android developer': 1,
#          'data engineer (отдел хранения и обработки данных)': 1,
#          'product owner на payments and transfers': 1,
#          'бизнес аналитик - супермаркет данных': 1,
#          'консультант 1c': 1,
#          'главный специалист отдела сопровождения и поддержки приложений': 1,
#          'product manager (литрес: платформа)': 1,
#          'it-специалист': 3,
#          'экономист по работе с арендаторами': 1,
#          'менеджер по поддержке продаж (vr/ar направление)': 1,
#          'старший системный аналитик': 1,
#          'testing engineer (privacy audit)': 1,
#          'младший системный аналитик': 1,
#          'full-stack разработчик (php / javascript)': 1,
#          'разработчик java, spring framework': 1,
#          'motion designer': 1,
#          'qa engineer (мой кредит)': 1,
#          'разработчик asp.net': 1,
#          'front-end react developer': 1,
#          'project менеджер / аккаунт-менеджер в digital агентство': 1,
#          'junior data scientist (рек.системы)': 1,
#          'программист-разработчик 1с': 1,
#          'qa engineer/тестировщик': 1,
#          'дизайнер/администратор сайта': 1,
#          'заместитель начальника it-отдела': 1,
#          'html-верстальщик / frontend разработчик': 1,
#          'бизнес-аналитик (команда интеграции продуктов экосистемы)': 1,
#          'technical product manager': 1,
#          'директор центра развития': 1,
#          'back-end разработчик / php программист': 1,
#          'php yii2 программист': 1,
#          'руководитель разработки': 1,
#          'рекрутер (менеджер по подбору персонала)': 1,
#          'веб-дизайнер, графический дизайнер': 1,
#          'lead blockchain / node.js разработчик': 1,
#          'javascript game developer': 1,
#          'html-верстальщик (11.86.2.)': 1,
#          'владелец продукта в направление индустрия 4.0 (ar и wearable devices)': 1,
#          'web-дизайнер, pr специалист': 1,
#          'frontend-разработчик (react разработчик)': 1,
#          'frontend разработчик (vue js)': 1,
#          'аналитик данных (дивизион ису)': 1,
#          'java-разработчик (start)': 1,
#          'младший разработчик c#': 1,
#          'инженер-разработчик (java)': 1,
#          'программист asp.net': 1,
#          'junior javascript developer': 1,
#          'разработчик ruby (lenta.ru)': 1,
#          'middle веб-программист php, js': 1,
#          'бизнес - аналитик (business intelligence analyst)': 1,
#          'главный системный аналитик [id38201]': 1,
#          'data analyst': 1,
#          'разработчик ios (swift)': 1,
#          'middle backend developer (go/php)': 1,
#          'менеджер продукта облачные функции': 1,
#          'бизнес- аналитик': 1,
#          'тестировщик': 2,
#          'программист php + фронт (js)': 1,
#          'специалист по информационным технологиям': 1,
#          'php-разработчик (fullstack)': 1,
#          'smm (интернет маркетолог/ веб-дизайнер)': 1,
#          'инженер-программист c++': 1,
#          'программист-разработчик java': 1,
#          'рhp программист': 1,
#          'инженер технической поддержки веб-сайта / мобильного приложения': 1,
#          'разработчик на wordpress': 1,
#          'инженер технической поддержки': 1,
#          ...})

# %%
import re

REGEXP_1 = re.compile(r'(.*?)scientist(.*?)')
REGEXP_2 = re.compile(r'(.*?)data(.*?)')
for vacancy in vacs:
    if REGEXP_1.fullmatch(vacancy['name'].lower()) or REGEXP_2.fullmatch(vacancy['name'].lower()):
        print(vacancy['name'])
# Out:
# Data-инженер/ разработчик DWH
# Продуктовый аналитик Big Data
# Product owner финтех (Big Data)
# Data Scientist
# Data Engineer (SQL)
# Преподаватель Python & Data Science
# Junior Data Analyst
# Data scientist/ Директор в управлении розничного моделирования
# Senior Data Engineer (Teradata/GreenPlum).
# Инженер-программист data science, computer vision (middle)
# Data Engineer
# Data Engineer
# Frontend-разработчик (проекты Data Science)
# Data engineer/DWH (Рекламные технологии)
# Data scientist
# Data engineer (ПРК)
# Разработчик платформы рекомендательных систем. Data Engineer.
# ETL-BigData Developer
# Разработчик / Data Engineer (Big Data)
# Стажер/Младший разработчик (DWH/ETL, Big data)
# Middle Data Science в R&D
# Data engineer (Отдел хранения и обработки данных)
# Junior Data Scientist (рек.системы)
# Data analyst
# Data scientist
# Senior Data Scientist
# Data Scientist
# Специалист-исследователь (Data science & information security)
# Data Scientist in Oil & Gas
# Senior Data Scientist
# Python Developer (Data Scientist)
# Senior Data Scientist в NLP лабораторию СКБ Контур

# %% [markdown]
# ### Посмотрим на зарплаты, как обещали

# %%
REGEXP_1 = re.compile(r'(.*?)scientist(.*?)')
REGEXP_2 = re.compile(r'(.*?)data(.*?)')
lower_bounds = []
upper_bounds = []
good_vacs = [vacancy for vacancy in vacs if REGEXP_1.fullmatch(vacancy['name'].lower()) or REGEXP_2.fullmatch(vacancy['name'].lower())]
for vacancy in good_vacs:
    if 'salary' in vacancy:
        print(vacancy['salary'])
# Out:
# None
# None
# None
# None
# None
# {'from': 150000, 'to': None, 'currency': 'RUR', 'gross': True}
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# {'from': 130000, 'to': 180000, 'currency': 'RUR', 'gross': True}
# None
# None
# None
# None
# None
# None
# None
# None
# None
# {'from': 3000, 'to': 3200, 'currency': 'USD', 'gross': True}
# None

# %% [markdown]
# ### ЖИЗНЬ БОЛЬ

# %% [markdown]
# Использовать API можно не только для текстовой информации, хотя чаще всего для нее. Вот пример работы c API Flickr https://gist.github.com/diff7/627a306d6d8e4ecd0162808deae7d244 для получения картинок. Для использования нужно импортировать API key на сайте и установить пакеты, которые импортируются в начале скрипта, если они еще не стоят. <br>
# https://vk.com/dev/methods - vk
#
# А если вам вдруг понравилось работать с апишками то вот здесь есть очень хороший проект с кучей всяких разных API со всего интернета.
# <a href="https://public-apis.xyz/">public-apis.xyz</a>

# %%
tok = 'b2541f06b2541f06b2541f063fb21ab6a8bb254b2541f06ec27e6299445529a3a6188f2'
url = 'https://api.vk.com/method/users.get?user_id=210700286&v=5.52&access_token={}'.format(tok)
resp = requests.get(url)

# %%
resp.text
# Out:
# '{"response":[{"id":210700286,"first_name":"Lindsey","last_name":"Stirling"}]}'

# %% [markdown]
# ###  Beautiful Soup
# Документация : https://www.crummy.com/software/BeautifulSoup/bs4/doc/ <br>
#
# Чаще всего через API можно получить намного больше интересной и качественной информации, убедиться в этом можно опять же зайдя на сайт public-apis.xyz там есть и статистика из онлайн игр отзывы по фильмам и много всего. Но  иногда сайты не предоставляют API, но данные на них все таки есть. (Мы не обсуждаем можно ли их использовать или нет, скорее всего об этом написано на самом сайте) Тогда приходится дейстовать подругому. <br>
# Посмотрим на примере сайта http://quotes.toscrape.com который был создан для как раз для практики данных навыков. <br>

# %%
link='http://quotes.toscrape.com'
page=requests.get(link)
if page.status_code == 200:  
    print(page.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#     <link rel="stylesheet" href="/static/bootstrap.min.css">
#     <link rel="stylesheet" href="/static/main.css">
# </head>
# <body>
#     <div class="container">
#         <div class="row header-box">
#             <div class="col-md-8">
#                 <h1>
#                     <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#                 </h1>
#             </div>
#             <div class="col-md-4">
#                 <p>
#
#                     <a href="/login">Login</a>
#
#                 </p>
#             </div>
#         </div>
#
#
# <div class="row">
#     <div class="col-md-8">
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
#         <span>by <small class="author" itemprop="author">Albert Einstein</small>
#         <a href="/author/Albert-Einstein">(about)</a>
#         </span>
#         <div class="tags">
#             Tags:
#             <meta class="keywords" itemprop="keywords" content="change,deep-thoughts,thinking,world" /    >
#
#             <a class="tag" href="/tag/change/page/1/">change</a>
#
#             <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
#
#             <a class="tag" href="/tag/thinking/page/1/">thinking</a>
#
#             <a class="tag" href="/tag/world/page/1/">world</a>
#
#         </div>
#     </div>
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“It is our choices, Harry, that show what we truly are, far more than our abilities.”</span>
#         <span>by <small class="author" itemprop="author">J.K. Rowling</small>
#         <a href="/author/J-K-Rowling">(about)</a>
#         </span>
#         <div class="tags">
#             Tags:
#             <meta class="keywords" itemprop="keywords" content="abilities,choices" /    >
#
#             <a class="tag" href="/tag/abilities/page/1/">abilities</a>
#
#             <a class="tag" href="/tag/choices/page/1/">choices</a>
#
#         </div>
#     </div>
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”</span>
#         <span>by <small class="author" itemprop="author">Albert Einstein</small>
#         <a href="/author/Albert-Einstein">(about)</a>
#         </span>
#         <div class="tags">
#             Tags:
#             <meta class="keywords" itemprop="keywords" content="inspirational,life,live,miracle,miracles" /    >
#
#             <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>
#
#             <a class="tag" href="/tag/life/page/1/">life</a>
#
#             <a class="tag" href="/tag/live/page/1/">live</a>
#
#             <a class="tag" href="/tag/miracle/page/1/">miracle</a>
#
#             <a class="tag" href="/tag/miracles/page/1/">miracles</a>
#
#         </div>
#     </div>
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”</span>
#         <span>by <small class="author" itemprop="author">Jane Austen</small>
#         <a href="/author/Jane-Austen">(about)</a>
#         </span>
#         <div class="tags">
#             Tags:
#             <meta class="keywords" itemprop="keywords" content="aliteracy,books,classic,humor" /    >
#
#             <a class="tag" href="/tag/aliteracy/page/1/">aliteracy</a>
#
#             <a class="tag" href="/tag/books/page/1/">books</a>
#
#             <a class="tag" href="/tag/classic/page/1/">classic</a>
#
#             <a class="tag" href="/tag/humor/page/1/">humor</a>
#
#         </div>
#     </div>
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“Imperfection is beauty, madness is genius and it&#39;s better to be absolutely ridiculous than absolutely boring.”</span>
#         <span>by <small class="author" itemprop="author">Marilyn Monroe</small>
#         <a href="/author/Marilyn-Monroe">(about)</a>
#         </span>
#         <div class="tags">
#             Tags:
#             <meta class="keywords" itemprop="keywords" content="be-yourself,inspirational" /    >
#
#             <a class="tag" href="/tag/be-yourself/page/1/">be-yourself</a>
#
#             <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>
#
#         </div>
#     </div>
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“Try not to become a man of success. Rather become a man of value.”</span>
#         <span>by <small class="author" itemprop="author">Albert Einstein</small>
#         <a href="/author/Albert-Einstein">(about)</a>
#         </span>
#         <div class="tags">
#             Tags:
#             <meta class="keywords" itemprop="keywords" content="adulthood,success,value" /    >
#
#             <a class="tag" href="/tag/adulthood/page/1/">adulthood</a>
#
#             <a class="tag" href="/tag/success/page/1/">success</a>
#
#             <a class="tag" href="/tag/value/page/1/">value</a>
#
#         </div>
#     </div>
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“It is better to be hated for what you are than to be loved for what you are not.”</span>
#         <span>by <small class="author" itemprop="author">André Gide</small>
#         <a href="/author/Andre-Gide">(about)</a>
#         </span>
#         <div class="tags">
#             Tags:
#             <meta class="keywords" itemprop="keywords" content="life,love" /    >
#
#             <a class="tag" href="/tag/life/page/1/">life</a>
#
#             <a class="tag" href="/tag/love/page/1/">love</a>
#
#         </div>
#     </div>
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“I have not failed. I&#39;ve just found 10,000 ways that won&#39;t work.”</span>
#         <span>by <small class="author" itemprop="author">Thomas A. Edison</small>
#         <a href="/author/Thomas-A-Edison">(about)</a>
#         </span>
#         <div class="tags">
#             Tags:
#             <meta class="keywords" itemprop="keywords" content="edison,failure,inspirational,paraphrased" /    >
#
#             <a class="tag" href="/tag/edison/page/1/">edison</a>
#
#             <a class="tag" href="/tag/failure/page/1/">failure</a>
#
#             <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>
#
#             <a class="tag" href="/tag/paraphrased/page/1/">paraphrased</a>
#
#         </div>
#     </div>
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“A woman is like a tea bag; you never know how strong it is until it&#39;s in hot water.”</span>
#         <span>by <small class="author" itemprop="author">Eleanor Roosevelt</small>
#         <a href="/author/Eleanor-Roosevelt">(about)</a>
#         </span>
#         <div class="tags">
#             Tags:
#             <meta class="keywords" itemprop="keywords" content="misattributed-eleanor-roosevelt" /    >
#
#             <a class="tag" href="/tag/misattributed-eleanor-roosevelt/page/1/">misattributed-eleanor-roosevelt</a>
#
#         </div>
#     </div>
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“A day without sunshine is like, you know, night.”</span>
#         <span>by <small class="author" itemprop="author">Steve Martin</small>
#         <a href="/author/Steve-Martin">(about)</a>
#         </span>
#         <div class="tags">
#             Tags:
#             <meta class="keywords" itemprop="keywords" content="humor,obvious,simile" /    >
#
#             <a class="tag" href="/tag/humor/page/1/">humor</a>
#
#             <a class="tag" href="/tag/obvious/page/1/">obvious</a>
#
#             <a class="tag" href="/tag/simile/page/1/">simile</a>
#
#         </div>
#     </div>
#
#     <nav>
#         <ul class="pager">
#
#
#             <li class="next">
#                 <a href="/page/2/">Next <span aria-hidden="true">&rarr;</span></a>
#             </li>
#
#         </ul>
#     </nav>
#     </div>
#     <div class="col-md-4 tags-box">
#
#             <h2>Top Ten tags</h2>
#
#             <span class="tag-item">
#             <a class="tag" style="font-size: 28px" href="/tag/love/">love</a>
#             </span>
#
#             <span class="tag-item">
#             <a class="tag" style="font-size: 26px" href="/tag/inspirational/">inspirational</a>
#             </span>
#
#             <span class="tag-item">
#             <a class="tag" style="font-size: 26px" href="/tag/life/">life</a>
#             </span>
#
#             <span class="tag-item">
#             <a class="tag" style="font-size: 24px" href="/tag/humor/">humor</a>
#             </span>
#
#             <span class="tag-item">
#             <a class="tag" style="font-size: 22px" href="/tag/books/">books</a>
#             </span>
#
#             <span class="tag-item">
#             <a class="tag" style="font-size: 14px" href="/tag/reading/">reading</a>
#             </span>
#
#             <span class="tag-item">
#             <a class="tag" style="font-size: 10px" href="/tag/friendship/">friendship</a>
#             </span>
#
#             <span class="tag-item">
#             <a class="tag" style="font-size: 8px" href="/tag/friends/">friends</a>
#             </span>
#
#             <span class="tag-item">
#             <a class="tag" style="font-size: 8px" href="/tag/truth/">truth</a>
#             </span>
#
#             <span class="tag-item">
#             <a class="tag" style="font-size: 6px" href="/tag/simile/">simile</a>
#             </span>
#
#
#     </div>
# </div>
#
#     </div>
#     <footer class="footer">
#         <div class="container">
#             <p class="text-muted">
#                 Quotes by: <a href="https://www.goodreads.com/quotes">GoodReads.com</a>
#             </p>
#             <p class="copyright">
#                 Made with <span class='sh-red'>❤</span> by <a href="https://scrapinghub.com">Scrapinghub</a>
#             </p>
#         </div>
#     </footer>
# </body>
# </html>

# %% [markdown]
# Как видно здесь присутствует какой - то текст, но ответ от страницы нам пришел так как видит ее браузер, т.е. с HTML тегами, сss и возможно JavaScript. Собственно что бы очистить страницу от HTML и всего прочего нам и нужна библиотека Beautiful Soup.

# %% [markdown]
# ### Чуть - чуть про HTML, если вы в курсе то пропустите.

# %% [markdown]
# <!DOCTYPE html>
# <html>
#     <head  style="color:red">Это простой пример HTML разметки используемый для форматирования текста.</head>
#     <div> Если нажаит на <strong>этот текст</strong> два раза, то вы увидите его так как его видит браузер.</div>
#     <body>
#         <h1><span class="cm-string"> Заголовок &lt;h1&gt; </span></h1>
#         <p>Параграф &lt;p&gt; </p>
#         <a href="www.nowhere.space">Ссылка в никуда</a>
#         <div>блок &lt;div&gt; </div>
#         <h2  style="color:red" > И конечно картинка: </h2>
#         <img src="https://cs6.pikabu.ru/post_img/big/2015/06/18/3/1434596941_632146314.jpg">
#         <p style="color:blue;">Для того что бы просмотреть страницу в HTML можно нажать правой кнопкой мыши и выбрать "inspect" в появившимся меню.</p>
#         <p>В общем, функционал зависит от браузера, но в целом должно появится что-то вроде этого. Можете попробовать с сайтом
#             <a href="http://quotes.toscrape.com"> http://quotes.toscrape.com </a></p>
#         <img src="https://mydatacareer.com/wp-content/uploads/2017/05/scraping3.png">
#     </body>
# </html>

# %% [markdown]
# #### Теперь мы знаем каким элементом страницы является тот или иной текст и сможем легко его извлечь с помощью библиотеки Beautiful Soup

# %% [markdown]
# Для установки библиотеки используйте следующую комманду в терминале (если на Linux)
#
# pip install beautifulsoup4

# %%
import bs4 as bs

link='http://quotes.toscrape.com'
page=requests.get(link)
if page.status_code == 200:  
    soup = bs.BeautifulSoup(page.content, 'html.parser')
    
soup.find_all('span', attrs={'class': 'text'}) #Как видно из картинки выше, наша цитата находится внутри тега span c классом text
# Out:
# [<span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>,
#  <span class="text" itemprop="text">“It is our choices, Harry, that show what we truly are, far more than our abilities.”</span>,
#  <span class="text" itemprop="text">“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”</span>,
#  <span class="text" itemprop="text">“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”</span>,
#  <span class="text" itemprop="text">“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”</span>,
#  <span class="text" itemprop="text">“Try not to become a man of success. Rather become a man of value.”</span>,
#  <span class="text" itemprop="text">“It is better to be hated for what you are than to be loved for what you are not.”</span>,
#  <span class="text" itemprop="text">“I have not failed. I've just found 10,000 ways that won't work.”</span>,
#  <span class="text" itemprop="text">“A woman is like a tea bag; you never know how strong it is until it's in hot water.”</span>,
#  <span class="text" itemprop="text">“A day without sunshine is like, you know, night.”</span>]

# %%
tags=soup.find_all('span', attrs={'class': 'text'})
tags[0].text
# Out:
# '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”'

# %%
[item.text for item in tags]
# Out:
# ['“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”',
#  '“It is our choices, Harry, that show what we truly are, far more than our abilities.”',
#  '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”',
#  '“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”',
#  "“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”",
#  '“Try not to become a man of success. Rather become a man of value.”',
#  '“It is better to be hated for what you are than to be loved for what you are not.”',
#  "“I have not failed. I've just found 10,000 ways that won't work.”",
#  "“A woman is like a tea bag; you never know how strong it is until it's in hot water.”",
#  '“A day without sunshine is like, you know, night.”']

# %% [markdown]
# ### Недостатки такого метода
#
# С помощью комбинации Beautiful Soup + Requests можно получить данные с большого числа сайтов. Но существует ряд недостатков.
#
# - Достаточно долго, так как процесс не параллелиться;
# - Для каждого нового сайта приходится писать все заново;
# - Некоторые сайты блокируют возможность парсинга, а некоторые используют JavaScript для отрисовки вместо HTML, тогда связки Beautiful Soup + Requests будет недостаточно.

# %% [markdown]
# ### Scrapy
# Scrapy это уже не библиотека, а полноценный фреймворк для парсинга данных с сайтов с кучей настроек и шикарным функционалом.
# Основным недостатком Scrapy является достаточно высокий порог входа, придется потратить некоторое время что бы разобраться во всех деталях. По дизайну фреймворк часто сравнивают с Django.
#
# Scrapy лучше использовать в следующих случаях:
# - Когда важна скорость скачивания;
# - Когда данные парсятся с большого числа однотипных сайтов;
# - Когда предстоит парсить данные с одого или нескольких сайтов на регулярной основе;
# - Когда нужно спарсить очень большой сайт.

# %% [markdown]
# ### Работа со Scrapy на примере сайте quotes.toscrape.com

# %% [markdown]
# В командной строке
#
# pip install scrapy
#
# дальнейшие команды нужно делать в системном питоне

# %%
#запустить Scrapy проект 
scrapy startproject proj

#в директории проекта должна появится папка spiders
cd scrapy/proj/proj/spiders 

#cоздайте в директории spiders фаил quotes_spider.py
nano quotes_spider.py

# %%
#содержимым файла будет соледующий код

# -*- coding: utf-8 -*-
import scrapy

class QuotesSpiderSpider(scrapy.Spider):
    name = 'quotes_spider' #название паука
    allowed_domains = ['quotes.toscrape.com'] 
    start_urls = ['http://quotes.toscrape.com/'] #ссылка с которой начинается парсинг

    def parse(self, response):
        #для выделения HTML тегов или сss декораторов Scrapy использует Xpath
        #по сути здесь мы передаем теже параметры которые передавали в Beautiful Soup
        quotes = response.xpath("//div[@class='quote']//span[@class='text']/text()").extract()
        yield {'quotes': quotes}

# %% [markdown]
# scrapy runspider quotes_spider.py -o quotes.json
