# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### О курсе:
#
# - 12 лекций
# - 2 лектора по 6 лекций
# - в первой части дз скорее всего 3 задачи из 6 на семинар (достаточно для зачета) / дз с работой в апи

# %% [markdown]
# ## О Языке:
# - Просто выучить и просто использовать
# - Free & OpenSource
# - Portable
# - Высокоуровневый
# - Интерпретируемый
# - Обьектно-ориентированный (все сущности в коде - объекты)
# - Строгая динамическая типизация
# - Батарейки в комплекте

# %%
using System;

namespace HelloWorld
{
    class Hello {
        static void Main(string[] args)
        {      // prints hello world
            System.Console.WriteLine("Hello World!");
        }
    }
}
# Out:
#   File "<ipython-input-2-b701c832cfa8>", line 1
#     using System;
#                ^
# SyntaxError: invalid syntax

# %%
#include <Windows.h>
 
HWND hMain = NULL;
 
//Стандартная функция обработки сообщений окном
LRESULT CALLBACK WndProc(HWND hWnd, UINT msg, WPARAM wParam, LPARAM lParam)
{
    UINT nCmd = HIWORD(wParam);
    UINT idCtrl = LOWORD(wParam);
    HWND hChild = (HWND)lParam;
 
    switch (msg)
    {   
    case WM_DESTROY:
        PostQuitMessage(0); //Закрываем приложение
        break;
 
    default: 
        return DefWindowProc(hWnd, msg, wParam, lParam); //возвращаем дефолтные значения     
    }
    return 0l;
}
 
//Главная функция приложения
INT WINAPI WinMain(HINSTANCE hInst, HINSTANCE, LPSTR, int)
{  
    MSG msg;
    WNDCLASS wc;
 
    memset(&wc, 0, sizeof(wc));
    wc.lpszClassName = L"MyWndClass"; //Название класса окна
    wc.hInstance = hInst ;
    wc.hCursor = LoadCursor(NULL, IDC_ARROW); //Курсор в окне
    wc.hbrBackground = (HBRUSH)(COLOR_3DFACE + 1); //Цвет окна
    wc.lpfnWndProc = WndProc;    
    RegisterClass(&wc); //Регистрируем класс окна
 
    //Создать окно
    hMain = CreateWindow(wc.lpszClassName, L"Окошко", WS_OVERLAPPEDWINDOW, 100, 100, 800, 600, 0, 0, hInst, 0);  
    ShowWindow(hMain, SW_SHOW); //Показать окно
    UpdateWindow(hMain); //Обновить окно
 
    //Стандартный цикл обработки сообщение приложением
    while (GetMessage(&msg, NULL, 0, 0))
    {
        TranslateMessage(&msg);
        DispatchMessage(&msg);
    }
    return (INT)msg.wParam;
}
# Out:
#   File "<ipython-input-3-318d1b62db10>", line 3
#     HWND hMain = NULL;
#              ^
# SyntaxError: invalid syntax

# %%
def solver(env, operand, params):
    lcl = env.create(params)
    peer = lcl.get_peer()
    return operand.integrate(peer, params)

# %%
a = 2
print(type(a))
print(id(a))
a = 'test'
print(type(a))
print(id(a))
# Out:
# <class 'int'>
# 4377830576
# <class 'str'>
# 4382013680

# %% [markdown]
# ## О жизни:
# - Python -- универсальный клей для API/бибилиотек/фреймворков/распределённых систем
# - Пригождается каждый день.
# - Не стоит писать на нём проекты с серьёзной инфраструктурой?

# %%
a = 7
  a = 8

# %%
import this

# %% [markdown]
# ## Откуда уши растут
#
# #### Язык ABC, 1985 год:

# %%
HOW TO RETURN words document:
   PUT {} IN collection
   FOR line IN document:
      FOR word IN split line:
         IF word not.in collection:
            INSERT word IN collection
   RETURN collection
# Out:
#   File "<ipython-input-14-a25f56dc380a>", line 1
#     HOW TO RETURN words document:
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 1991 год, Гвидо ван Россум

# %% [markdown]
# ## Python 2 vs Python 3
#
# <center> <img src="http://i.imgur.com/IBkzM7E.jpg" width=200px /> </center>
#
#
# - Существует две официальных, несовместимых версии Python - 2.x и 3.x
# - 2.x -- поддерживается, никакие новые фичи в нем не появляются
# - Мы будем говорить про Python 3 и немного поговорим о Python 2

# %% [markdown]
# # Python это просто

# %%
for i in range(10):
    if not (i % 3 == 0):
        print(i ** 2)
# Out:
# 1
# 4
# 16
# 25
# 49
# 64

# %% [markdown]
# # Базовые типы и операции
#
# ### Арифметические
#
# int и float

# %%
5 + 6 * (2 ** 2) / 7
# Out:
# 8.428571428571429

# %%
(1 << 4) | (4 >> 2)
# Out:
# 17

# %%
print(type(2))
print(type(str(2)))
x = float('inf')
print(type(x))
print(x)
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# inf

# %% [markdown]
# ### Логические

# %%
True or False
# Out:
# True

# %%
not False or non_existant # lazy evaluation
# Out:
# True

# %%
7 or True
# Out:
# 7

# %%
(2 < 3) and (3 < 5)
# Out:
# True

# %%
1 < 2 < 3
# Out:
# True

# %%
False == False != True
# Out:
# True

# %% [markdown]
# ### None

# %%
None

# %%
None == None
# Out:
# True

# %%
None is None
# Out:
# True

# %%
bool(None)
# Out:
# False

# %% [markdown]
# ### Переменные

# %%
a = 2
b = 12 
c = b / a + 5

print(c)
# Out:
# 11.0

# %%
c = b % a
print(c)
# Out:
# 0

# %%
c = b // a
print(c)
# Out:
# 6

# %%
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-e983f374794d> in <module>
# ----> 1 d
#
# NameError: name 'd' is not defined

# %% [markdown]
# ### Строковые типы

# %%
s = "Hello"
print(s[len(s)])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-56-c7c031568a07> in <module>
#       1 s = "Hello"
# ----> 2 print(s[len(s)])
#
# IndexError: string index out of range

# %%
"May the fource " + "be with you"
# Out:
# 'May the fource be with you'

# %%
"five" + 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-849f54e3fc1e> in <module>
# ----> 1 "five" + 6
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("Hi! " * 10)
# Out:
# Hi! Hi! Hi! Hi! Hi! Hi! Hi! Hi! Hi! Hi!

# %%
t = """      Hi!       

"""

print(t.strip())
# Out:
# Hi!

# %% [markdown]
# # Управляющие Конструкции
#
# ### if

# %%
a = 2

if a > 5:
    print('> 5')
elif a == 5:
    print('5')
elif a < 5:
    print('< 5')
else:
    print('HOW?!')
# Out:
# < 5

# %% [markdown]
# ###  while

# %%
a = 10

while a > 5:
    print(a)
    a -= 2
# Out:
# 10
# 8
# 6

# %%
a = 10

while a > 5:
    print(a)
    a -= 2
else:
    print('Done')
# Out:
# 10
# 8
# 6
# Done

# %%
a = 10
while a > 5:
    a += 2
    a -= 2
    print(a)
# Out:
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# ...

# %% [markdown]
# ### for

# %%
for i in range(10):
    print(i)

# %%
for i in [0, 1, 2, 3, 4, 5]:
    print(str(i) * i, end=' ')
else:
    print('Done')
# Out:
#  1 22 333 4444 55555 Done

# %%
for char in "test":
    print(char, end=' ')
# Out:
# t e s t

# %%
for i in range(2, 10, 2):
    print(i ** 2, end=' ')
# Out:
# 4 16 36 64

# %%
for i in range(9):
    if i % 2 :
        continue
    print(str(i) * i, end=' ')
# Out:
#  22 4444 666666 88888888

# %%
# %%time
x = 1
for i in range(999999):
    x += 1

# %% [markdown]
# continue и break работают так же, как в любом другом языке

# %% [markdown]
# ### Тернарный оператор

# %%
b = 10
a = b / 2 if b % 2 else b - 1

print(a)
# Out:
# 9

# %% [markdown]
# ### Функции

# %%
import math

def find_roots(a, b, c):
    discriminant = b * b - 4 * a * c
    if discriminant > 0:
        root_1 = (-b + math.sqrt(discriminant)) / (2 * a)
        root_2 = (-b - math.sqrt(discriminant)) / (2 * a)
    elif discriminant == 0:
        root_1 = root_2 = -b / (2 * a)
    elif discriminant < 0:
        root_1 = None
        root_2 = None

    return [root_1, root_2]


root_1 = find_roots(1, 7, 7)[0]
root_2 = find_roots(1, 7, 7)[1]
print(root_1, root_2)
root_1 = find_roots(1, 2, 1)[0]
root_2 = find_roots(1, 2, 1)[1]
print(root_1, root_2)
root_1 = find_roots(1, 1, 1)[0]
root_2 = find_roots(1, 1, 1)[1]
print(root_1, root_2)
# Out:
# 7.416198487095663

# %% [markdown]
# ## Пользовательский ввод

# %%
a = input()
b = input()
print(int(a) * int(b))
# Out:
# 1
# 2
# 2

# %%
snake_case
CamelCase
proccess_case()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-f496e91ac931> in <module>
# ----> 1 snake_case
#       2 CamelCase
#
# NameError: name 'snake_case' is not defined

# %%
https://www.python.org/dev/peps/pep-0008/
https://www.python.org/dev/peps/pep-0020/#id3
zen of python
монти пайтон
pep8
# Out:
#   File "<ipython-input-84-596e93f84d67>", line 1
#     https://www.python.org/dev/peps/pep-0008/
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# Переменные != Обьекты
# Объекты это сущности с которыми вы взаимодействуете в коде (числа, строки, контейнеры, функции, файлы etc)
# Переменные это именованные ссылки на обьекты (на один объект может быть несколько ссылок)
# Управление памятью
# Не нужно заботиться о времени жизни обьектов. За вас об этом подумает интерпретатор, с помощью механизма подсчета ссылок.
# Когда не останется ни одной переменной указывающей на ваш объект - он удалится
